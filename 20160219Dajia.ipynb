# %%
import requests
url = 'http://mlb.mlb.com/home'
res = requests.get(url)

# %%
print res.text
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="lt-ie9 lt-ie8 lt-ie7" lang="en_US"> <![endif]-->
# <!--[if IE 7]> <html class="lt-ie9 lt-ie8" lang="en_US"> <![endif]-->
# <!--[if IE 8]> <html class="lt-ie9" lang="en_US"> <![endif]-->
# <!--[if IE 9]> <html class="ie9" lang="en_US"> <![endif]-->
# <!--[if gt IE 9]><!--> <html class="no-js" lang="en_US"> <!--<![endif]-->
# <head>
# <title>MLB.com | The Official Site of Major League Baseball</title>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta http-equiv="content-type" content="text/html; charset=UTF-8"/>
# <meta http-equiv="content-language" content="en_US">
# <meta name="description" content="The Official Site of Major League Baseball"/>
# <meta name="keywords" content="MLB, Baseball, Major League Baseball"/>
# <meta http-equiv="Expires" CONTENT="0" />
# <meta http-equiv="Cache-Control" CONTENT="no-store" />
# <meta http-equiv="Pragma" CONTENT="no-cache" />
# <meta name="image" content="http://www.mlb.com/">
# <meta name="tracking_host" content="http://www.mlb.com" />
# <meta name="BUILD" content="true" />
# <meta name="clubId" content="mlb" />
# <meta name="sectionId" content="homepage" />
# <meta name="env" content="prodweb1" />
# <meta name="server_url" content="http://www.mlb.com" />
# <meta name="secure_url" content="https://secure.mlb.com" />
# <meta name="cache_url" content="http://mlb.mlb.com" />
# <meta name="mobile_url" content="http://m.mlb.com" />
# <meta name="bam:version" content="4.2.1">
# <meta name="bam:section_version" content="4.3.2">
# <meta property="og:title" content="MLB.com" />
# <meta itemprop="name" content="MLB.com" />
# <meta property="og:site_name" content="MLB.com" />
# <link rel="canonical" href="http://mlb.mlb.com/home" />
# <meta property="og:url" content="http://mlb.mlb.com/home" />
# <meta property="og:type" content="website" />
# <meta name="twitter:card" value="summary" />
# <meta name="twitter:site" value="@mlb" />
# <meta name="twitter:url" value="http://mlb.mlb.com/home" />
# <meta name="twitter:title" value="MLB.com" />
# <meta name="twitter:description" value="The Official Site of Major League Baseball" />
# <meta name="twitter:image" value="http://mlb.mlb.com/mlb/images/team_logos/social_media/og_1200x630_image/mlb_1200x630.jpg" />
# <meta name="twitter:widgets:csp" content="on"/>
# <meta name="image" content="http://mlb.mlb.com/mlb/images/team_logos/social_media/og_1200x630_image/mlb_1200x630.jpg">
# <meta property="og:image" content="http://mlb.mlb.com/mlb/images/team_logos/social_media/og_1200x630_image/mlb_1200x630.jpg" />
# <meta itemprop="image" content="http://mlb.mlb.com/mlb/images/team_logos/social_media/og_1200x630_image/mlb_1200x630.jpg" />
# <link rel="image_src" href="http://mlb.mlb.com/mlb/images/team_logos/social_media/og_1200x630_image/mlb_1200x630.jpg" />
# <meta name="apple-itunes-app" content="app-id=493619333, affiliate-data=at=10l3Hj&amp;ct=mobile_AtBat_HPinterst" />
# <meta name="apple-mobile-web-app-title" content="MLB.com" />
# <link rel="apple-touch-icon" sizes="57x57" href="http://ui.bamstatic.com//clubs/mlb/images/icons/iOS/apple-icon-57x57.png" />
# <link rel="apple-touch-icon" sizes="72x72" href="http://ui.bamstatic.com//clubs/mlb/images/icons/iOS/apple-icon-72x72.png" />
# <link rel="apple-touch-icon" sizes="114x114" href="http://ui.bamstatic.com//clubs/mlb/images/icons/iOS/apple-icon-114x114.png" />
# <link rel="apple-touch-icon" sizes="144x144" href="http://ui.bamstatic.com//clubs/mlb/images/icons/iOS/apple-icon-144x144.png" />
# <meta name="abTests" content="mediawall" />
# <meta name="config" data-type="json" content="{&quot;miniscoreboards&quot;:[],&quot;mini_scoreboard&quot;:{&quot;date&quot;:&quot;&quot;,&quot;header&quot;:&quot;none&quot;,&quot;mode&quot;:&quot;off_season&quot;},&quot;abTests&quot;:&quot;mediawall&quot;,&quot;default_video_tab&quot;:&quot;mlbtv_ad&quot;,&quot;events&quot;:[{&quot;date&quot;:&quot;Feb. 28&quot;,&quot;event&quot;:&quot;First Spring Training game&quot;,&quot;link&quot;:&quot;http://mlb.mlb.com/mlb/schedule/index.jsp#date=02/28/2016&quot;},{&quot;date&quot;:&quot;Mar. 17&quot;,&quot;event&quot;:&quot;WBC Qualifiers, Mexicali and Panama City&quot;,&quot;link&quot;:&quot;http://m.worldbaseballclassic.com/&quot;},{&quot;date&quot;:&quot;April 3&quot;,&quot;event&quot;:&quot;Opening Day &amp; Opening Night&quot;,&quot;link&quot;:&quot;http://m.mlb.com/news/article/157684628/&quot;},{&quot;date&quot;:&quot;April 4&quot;,&quot;event&quot;:&quot;Opening Day&quot;,&quot;link&quot;:&quot;http://mlb.mlb.com/mlb/schedule/#date=04/04/2016&quot;},{&quot;date&quot;:&quot;April 15&quot;,&quot;event&quot;:&quot;Jackie Robinson Day&quot;,&quot;link&quot;:&quot;http://web.mlbcommunity.org/index.jsp?content=programs&amp;program=jackie_robinson_foundation&quot;},{&quot;date&quot;:&quot;May 31&quot;,&quot;event&quot;:&quot;Roberto Clemente Day&quot;,&quot;link&quot;:&quot;http://m.mlb.com/news/article/157695122&quot;},{&quot;date&quot;:&quot;June 9-11&quot;,&quot;event&quot;:&quot;MLB Draft&quot;,&quot;link&quot;:&quot;http://m.mlb.com/news/article/158196902/&quot;},{&quot;date&quot;:&quot;July 12&quot;,&quot;event&quot;:&quot;All-Star Game in San Diego&quot;,&quot;link&quot;:&quot;http://mlb.mlb.com/mlb/events/all_star/y2016/index.jsp&quot;},{&quot;date&quot;:&quot;July 24&quot;,&quot;event&quot;:&quot;Hall of Fame Induction Day&quot;,&quot;link&quot;:&quot;http://m.mlb.com/hof&quot;},{&quot;date&quot;:&quot;Aug. 1&quot;,&quot;event&quot;:&quot;Non-waiver Trade Deadline&quot;,&quot;link&quot;:&quot;http://m.mlb.com/news/article/162485552/&quot;},{&quot;date&quot;:&quot;Sept. 22&quot;,&quot;event&quot;:&quot;WBC Qualifiers, Brooklyn, N.Y.&quot;,&quot;link&quot;:&quot;http://m.worldbaseballclassic.com/&quot;}],&quot;video_module_live_mode&quot;:{&quot;enable&quot;:true,&quot;override&quot;:true},&quot;mini-tab&quot;:&quot;0&quot;,&quot;mini-header-image&quot;:[],&quot;sponsor-image&quot;:[],&quot;breaking_news&quot;:{&quot;url&quot;:&quot;&quot;,&quot;text&quot;:&quot;&quot;},&quot;header&quot;:{&quot;image&quot;:&quot;&quot;,&quot;url&quot;:&quot;&quot;,&quot;alt&quot;:&quot;&quot;},&quot;live_game_feed&quot;:{&quot;enable&quot;:false,&quot;override&quot;:false}}" />
# <meta name="serverTime" content="2016-02-18T21:13:41-05:00" />
# <meta name="flipTime" content="11:00" />
# <meta name="flipTimeZoneOffset" content="-0500" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
# <script type="text/javascript">
# var _sf_startpt = (new Date()).getTime(); // Chartbeat
# </script>
# <!-- global -->
# <link type="text/css" rel="stylesheet" href="http://ui.bamstatic.com//clubs/mlb/css-deploy/4.2.1/prod/mlb-global-build.css?v=4.2.1" />
# <!-- page -->
# <link type="text/css" rel="stylesheet" href="/sections/rhome/css-deploy/4.3.2/prod/home-build.css?v=4.3.2" />
# <!-- responsive -->
# <link type="text/css" rel="alternate" title="responsive" href="/sections/rhome/css-deploy/4.3.2/prod/home-responsive-build.css?v=4.3.2" disabled/>
# <!-- news alert -->
# <link type="text/css" rel="stylesheet" href="http://ui.bamstatic.com/fedapp/newsalert/builds/0.0.0/style/main.css" />
# <!-- postseason tunein -->
# <link type="text/css" rel="stylesheet" href="http://ui.bamstatic.com/clubs/mlb/css-deploy/postseason-tunein.css" />
# <style>
# /** mlb homepage - player tracking **/
# /** TODO Move this to CSS file eventually */
# .trending-items-container .trending-item .flag.player-tracking {
# background-color: #00c0ff;
# }
# .trending-items-container .trending-item .flag.player-tracking strong:after {
# border-bottom-color: #00c0ff;
# border-left-color: #00c0ff;
# border-top-color: #00c0ff;
# }
# .trending-item.player-tracking .player-tracking-ad {
# width: 145px;
# height: 20px;
# float: right;
# }
# footer #footer-logos dl#footer-social dd.twitter a {
# background-position: 0 -70px;
# }
# footer #footer-logos dl#footer-social dd.google a {
# background-position: 0 -186px;
# }
# /* MINI Scoreboard */
# .device-tablet .fgod-end-season {
# display: none;
# }
# .device-tablet .stHead .sponsor,
# .device-phone .stHead .sponsor {
# display:none;
# }
# @media (max-width:989px) and (min-width:768px), (max-aspect-ratio:13/9) and (max-width:767px) and (min-width:600px), (max-width:767px) and (min-aspect-ratio:13/9), (max-width:599px) {
# .touch .container .aside-content,
# .touch .bam-minisb {
# height: 100px;
# }
# .touch .container .aside-content.event,
# .touch .event .bam-minisb {
# height: 140px;
# overflow: hidden;
# }
# .device-phone.touch .container .aside-content.event,
# .device-phone.touch .event .bam-minisb {
# height: auto;
# }
# .bam-minisb .rs .et {
# display: none;
# }
# }
# .bam-minisb .openingHeader img {
# display: block;
# padding-bottom: 15px;
# width: 100%;
# }
# .pscontainer .mlb-locators {
# display: none !important;
# }
# .pscontainer .tv .fs1 {
# background-position: -141px -85px;
# width: 30px;
# }
# .pscontainer .tv .fs1.snet {
# left:45px;
# }
# .pscontainer .tv .mlbn.snet {
# left:85px;
# }
# .pscontainer .tv .postseasontv {
# background-position: -585px -139px;
# width: 85px;
# }
# .pscontainer .wc_foot .tbs {
# left: 100px;
# }
# .pscontainer .tv .fs1.snet::after,
# .pscontainer .tv .mlbn.snet::after,
# .pscontainer .tv .fox.snet::after {
# content: "";
# width: 24px;
# height: 24px;
# left: 35px;
# background: url(/sections/rhome/packages/mini-scoreboard/assets/2015/postseason/2015_minisb_wired_sprite@2x.png) no-repeat -206px -84px;
# background-size: 800px auto;
# display: block;
# position: relative;
# float: left;
# }
# .pscontainer .tv .fox {
# background-position: -28px -85px;
# }
# .pscontainer .wc_foot .fox,
# .pscontainer .wc_foot .fs1.snet {
# left: 90px;
# }
# .pscontainer .postseason_buttons .highlights {
# background: url(/sections/rhome/packages/mini-scoreboard/assets/2015/postseason/2015_minisb_wired_sprite@2x.png) no-repeat -17px -116px;
# background-size: 800px auto;
# }
# .mwContainer .mw_panel_game a.mw_button_tv {
# /* display:none; */
# }
# </style>
# <!--[if lt IE 9]>
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/headers/builds/1.0.1/style/header.legacy.css" />
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/headers/club-builds/1.0.1/mlb/style/mlb.legacy.css" />
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/footers/builds/footer/0.0.0/styles/footer.css" />
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/footers/builds/club-styles/mlb/0.0.0/styles/mlb.css" />
# <![endif]-->
# <!--[if gt IE 8]><!-->
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/headers/builds/1.0.1/style/header.css" />
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/headers/club-builds/1.0.1/mlb/style/mlb.css" />
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/footers/builds/footer/0.0.0/styles/footer.css" />
# <link rel="stylesheet" type="text/css" href="http://ui.bamstatic.com//fedapp/footers/builds/club-styles/mlb/0.0.0/styles/mlb.css" />
# <!--<![endif]-->
# <!--[if lte IE 7 ]>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/shims/ie7/json2.js"></script>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/shims/ie7/localStorage.js"></script>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/shims/ie8/es5shim.js"></script>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/shims/ie8/html5shiv.js"></script>
# <![endif]-->
# <!--[if (lte IE 9)&(gt IE 7) ]>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/shims/ie8/es5shim.js"></script>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/shims/ie8/html5shiv.js"></script>
# <![endif]-->
# <script src="http://mlb.mlb.com/bundle?js=http://ui.bamstatic.com//bridge/lib/modernizr/modernizr-touch.js&js=http://mlb.mlb.com/bower_components/device/builds/2.2.0/device.js&js=http://ui.bamstatic.com//bridge/core/js/deviceTypeBootStrap.js&v=4.2.1"></script>
# <script type="text/javascript">
# // load pingdom
# if (DeviceType.device === "desktop") {
# var _prum = [['id', '52275670abe53dbe6e000000'],
# ['mark', 'firstbyte', (new Date()).getTime()]];
# (function() {
# var s = document.getElementsByTagName('script')[0],
# p = document.createElement('script');
# p.async = 'async';
# p.src = '//rum-static.pingdom.net/prum.min.js';
# s.parentNode.insertBefore(p, s);
# })();
# }
# </script>
# <script src="//cdn.evergage.com/beacon/mlb/engage/scripts/evergage.min.js" type="text/javascript"></script>
# </head>
# <body id="rhome_index" class="web generic">
# <script type="text/javascript">
# var omDomain = document.location.hostname.toLowerCase();
# var isProd = ( (omDomain.indexOf("betasecure.") == -1) && (omDomain.indexOf("beta.") == -1) && (omDomain.indexOf("dev-") == -1) && (omDomain.indexOf("qa.") == -1) && (omDomain.indexOf("qa2.") == -1) ) ? true : false;
# var s_device_suite = (DeviceType.device === "phone") ? "mlbglobal08,mlbwap" : "mlbglobal08,mlbcom08";
# var s_rsid = (isProd) ? s_device_suite : "devmlbglobal";
# var s_account = s_rsid; // for legacy g code tracking
# </script>
# <script type="text/javascript" src="http://ui.bamstatic.com//bridge/core/js/mlbamscv2.js"></script>
# <script type="text/javascript">
# s.pageName = "Major League Baseball: Homepage";
# s.channel = "Homepage";
# s.prop1 = "";
# s.currencyCode= "USD";
# if (DeviceType.device === "phone") {
# s.prop8 = "Mobile Web";
# }
# s.prop24 = s_rsid;
# s.campaign = s.getQueryParam("partnerId");
# s.eVar1 = s.getQueryParam("vbID");
# s.eVar2 = s.prop4;
# s.eVar4 = s.getQueryParam("affiliateId");
# s.eVar8 = "";
# s.eVar9 = "";
# s.eVar14 = s.getQueryParam("tcid");
# s.eVar21 = s.getQueryParam("tdl");
# s.eVar22 = s.getQueryParam("tfl");
# s.eVar25 = s.getQueryParam("mlbkw");
# s.events = "event4";
# function urlDecode(str){
# str = str.replace(/\+/g, " ");
# str = str.replace(/\%2[B,b]/g, "+");
# str = unescape(str);
# return str;
# }
# function GetCookieVal (offset) {
# var endstr = document.cookie.indexOf (";", offset);
# if (endstr == -1) endstr = document.cookie.length;
# var val=document.cookie.substring(offset, endstr);
# return urlDecode(val);
# }
# function GetCookie (name) {
# var arg = name + "=";
# var alen = arg.length;
# var clen = document.cookie.length;
# var i = 0;
# while (i < clen) {
# var j = i + alen;
# if (document.cookie.substring(i, j) == arg) { return GetCookieVal (j); }
# i = document.cookie.indexOf(" ", i) + 1;
# if (i == 0) break;
# }
# return null;
# }
# function GetOrientation () {
# var width = window.innerWidth || document.documentElement.clientWidth;
# var height = window.innerHeight || document.documentElement.clientHeight;
# var orientation = (height >= width) ? "Portrait" : "Landscape";
# return orientation;
# }
# function capitalizeFirstLetter (string) {
# return string.charAt(0).toUpperCase() + string.slice(1);
# }
# s.prop5 = s.eVar34 = (DeviceType.device === 'phone') ? 'Smartphone' : capitalizeFirstLetter(DeviceType.device);
# s.prop6 = s.eVar35 = GetOrientation();
# s.prop7 = s.eVar36 = (s.prop5 + ": " + s.prop6);
# s.prop22 = s.eVar11 = GetCookie('ipid') || '';
# s.linkInternalFilters="javascript:,mlb,mlb"
# /********* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# var s_code=s.t();if(s_code)document.write(s_code)//--></script>
# <script type="text/javascript"><!--
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
# //--></script><noscript><a href="http://www.omniture.com" title="Web Analytics"><img
# src="http://mlbreloaded.112.2O7.net/b/ss/mlbreloaded/1/H.13--NS/0?[AQB]&cdp=3&[AQE]"
# height="1" width="1" border="0" alt="" /></a></noscript><!--/DO NOT REMOVE/-->
# <div id="ad-phone-header" class="ad-responsive-slot">
# <div id="ad-pushdown-320x50" class="ad-responsive-size" data-thresholds="[0]" data-sizes="[[320,50]]" data-targeting='{"pos":"1"}'></div>
# </div>
# <div id="news-alert"></div>
# <header class="navbar">
# <div class="menu-container" data-is-mlb>
# <div class="languagebar">
# <div class="width-container">
# <a class="languagebar__logo" href="http://mlb.mlb.com" data-phone-href="http://mlb.mlb.com"><img src="/images/8/5/8/113325858/mlb.com_85zr0j8l.png" alt="" onerror="this.onerror=null;this.src='/assets/images/0/8/6/113326086/cuts/mlb.com_0r2ty9nf_mjkvcybr.png';" /></a>
# <nav class="languagebar__site-language">
# <a href="http://mlbjapan.tumblr.com/" data-phone-href="http://mlbjapan.tumblr.com/">&#26085;&#26412;&#35486;</a>
# <a href="http://mlb.mlb.com/es/index.jsp?c_id=mlb" data-phone-href="http://m.mlb.comm.es.mlb.com">Espa&#241;ol</a>
# <a href="http://www.mlbkorea.com" data-phone-href="">&#54620;&#44397;&#50612;</a>
# <a href="http://mlb.tw" data-phone-href="">&#32321;&#39636;&#20013;&#25991;</a>
# </nav>
# <span class="languagebar__title"></span>
# </div>
# </div>
# <div class="main-container">
# <div class="logobar-container">
# <div class="width-container">
# <a class="logobar__logo" href="http://mlb.mlb.com" data-phone-href="http://mlb.mlb.com"><img src="/documents/8/0/4/111192804/mlb_logo_prod3_1_fqk7toel.svg" alt="MLB Wired Logo" onerror="this.onerror=null;this.src='/assets/images/7/8/4/111194784/cuts/mlb_header_1X_pqj47ro2_0f6m7qfu.png';" /></a>
# <div class="logobar__marketing">
# <div class="buttonContainer">
# <span class="searchButton__container">
# <form action="http://mlb.mlb.com/search/?c_id=mlb" class="searchForm" id="searchForm">
# <input name="ps_lastname" class="searchForm__input" placeholder="Search" type="text" value="" autocomplete="off" autocorrect="off" autocapitalization="off" />
# <div class="searchButton__icon"></div>
# <ul></ul>
# </form>
# </span>
# <span class="accountButton__container"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="navbar-container">
# <div class="width-container">
# <nav class="navbar-container__navbar">
# <button class="navbar-container__button"><span class="button__label">Sections</span><span class="arrow arrow__down"></span></button>
# <a href="http://m.mlb.com/scoreboard" data-phone-href="http://m.mlb.com/scoreboard" class="menu-item menu-item--scoreboard" data-wired-order="1" data-no-panel>Scores</a>
# <a href="http://m.mlb.com/news?tcid=nav_mlb_news" data-phone-href="http://m.mlb.com/news" class="menu-item menu-item--news" data-wired-order="2">News</a>
# <a href="http://m.mlb.com/video/?affiliateId=clubMEGAMENU" data-phone-href="http://m.mlb.com/video/?affiliateId=clubMEGAMENU" class="menu-item menu-item--video" data-wired-order="3">Video</a>
# <a href="http://mlb.mlb.com/stats/sortable.jsp" data-phone-href="http://m.mlb.com/stats" class="menu-item menu-item--stats" data-wired-order="4">Stats</a>
# <a href="http://mlb.mlb.com/mlb/standings/index.jsp" data-phone-href="http://m.mlb.com/standings" class="menu-item menu-item--standings" data-wired-order="5">Standings</a>
# <a href="http://mlb.mlb.com/mlb/schedule/index.jsp#date=04/03/2016" data-phone-href="http://m.mlb.com/schedule/2016/04/03/?season=2016" class="menu-item menu-item--schedule" data-wired-order="6">Schedule</a>
# <a href="http://mlb.mlb.com/mlb/players/?tcid=nav_mlb_players" data-phone-href="" class="menu-item menu-item--players" data-wired-order="7">Players</a>
# <a href="http://mlb.mlb.com/mlb/tickets/?tcid=nav_mlb_tickets&amp;y=2015" data-phone-href="http://m.mlb.com/tickets" class="menu-item menu-item--tickets" data-wired-order="8">Tickets</a>
# <a href="http://mlb.mlb.com/mobile/?tcid=nav_mlb_mobile" data-phone-href="http://m.mlb.com/apps/" class="menu-item menu-item--mobile" data-wired-order="9">Apps</a>
# <a href="http://shop.mlb.com/?partnerId=X23M1TV388R1-10" data-phone-href="http://mshop.mlb.com/?partnerId=X23M1TV388R1-10" class="menu-item menu-item--shop" data-wired-order="10">Shop</a>
# <a href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU" data-phone-href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU" class="menu-item menu-item--mlbtv" data-wired-order="11">MLB.TV</a>
# <a href="http://mlb.mlb.com/mlb/fantasy/?tcid=nav_mlb_fantasy&amp;y=2016" data-phone-href="http://m.mlb.com/fantasy" class="menu-item menu-item--fantasy" data-wired-order="12">Fantasy</a>
# <a href="" data-phone-href="http://auction.mlb.com/" class="menu-item menu-item--Auction" data-no-panel>Auction</a>
# <a href="http://mlb.mlb.com/team/index.jsp" data-phone-href="http://m.mlb.com/teams" class="menu-item menu-item--teams" data-wired-order="13">Teams</a>
# </nav>
# <nav class="navbar-container__overflow">
# <ul class="menu-container__overflow">
# <li class="menu-item menu-item--scoreboard" data-wired-order="1" data-no-panel>
# <a class="menu-item--link" href="http://m.mlb.com/scoreboard" data-phone-href="http://m.mlb.com/scoreboard">Scores</a>
# </li>
# <li class="menu-item menu-item--news" data-wired-order="2">
# <a class="menu-item--link" href="http://m.mlb.com/news?tcid=nav_mlb_news" data-phone-href="http://m.mlb.com/news">News<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--media-panel" data-title="News">
# <h2 class="panel__title">News</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--recent-media">
# <h2 class="module__title">News</h2>
# <ul>
# </ul></div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">In This Section</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/news/probable_pitchers/index.jsp?c_id=mlb" data-phone-href="">
# Probable Pitchers
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/prospects/2016" data-phone-href="http://m.mlb.com/prospects/2016">
# Top Prospects
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/wsfb/news/injuries.jsp?tcid=nav_mlb_news" data-phone-href="">
# Injury Updates
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/transactions/?tcid=mm_mlb_news" data-phone-href="">
# Transactions
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/hof" data-phone-href="http://m.mlb.com/hof">
# Hall of Fame
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/history/?tcid=mm_mlb_news" data-phone-href="">
# History
# </a>
# </li>
# <li>
# <a href="https://www.worldseries.com/" data-phone-href="https://www.worldseries.com/">
# World Series
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/schedule/events" data-phone-href="http://m.mlb.com/schedule/events">
# Events
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/events/draft/y2015/" data-phone-href="http://mlb.mlb.com/mlb/events/draft/y2015/">
# MLB Draft
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/events/all_star/y2015/index.jsp" data-phone-href="http://m.mlb.com/asg">
# All-Star Game
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/presspass/gamenotes.jsp?c_id=mlb" data-phone-href="">
# Game Notes
# </a>
# </li>
# </ul>
# </div> <div class="panel__module panel__module--related-links">
# <h2 class="module__title">Featured</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/cutfour/index.jsp" data-phone-href="http://mlb.mlb.com/cutfour/index.jsp">Cut 4</a>
# </li>
# <li>
# <a href="http://web.usabaseball.com/playball/" data-phone-href="http://web.usabaseball.com/playball/">Play Ball</a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/news/columnists/index.jsp" data-phone-href="">Voices</a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/news/prospects/index.jsp" data-phone-href="">Pipeline</a>
# </li>
# <li data-appears="2015-10-29T00:00:00-0400">
# <a href="http://m.mlb.com/awards" data-phone-href="http://m.mlb.com/awards">2015 Awards</a>
# </li>
# <li>
# <a href="http://www.sportsonearth.com/" data-phone-href="http://www.sportsonearth.com/">Sports on Earth</a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/schedule/ps.jsp" data-phone-href="http://mlb.mlb.com/mlb/schedule/ps.jsp">Postseason</a>
# </li>
# <li>
# <a href="http://m.mlb.com/cutfour/2015/09/11/148718578/video-ferrell-takes-the-field-trailers-for-10-mlb-teams" data-phone-href="http://m.mlb.com/cutfour/2015/09/11/148718578/video-ferrell-takes-the-field-trailers-for-10-mlb-teams">Will Ferrell</a>
# </li>
# <li>
# <a href="https://securea.mlb.com/mlb/awards/y2015/mlb-awards/" data-phone-href="https://securea.mlb.com/mlb/awards/y2015/mlb-awards/">#AwardWorthy</a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/es/news/index.jsp?c_id=mlb" data-phone-href="">Espanol</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--video" data-wired-order="3">
# <a class="menu-item--link" href="http://m.mlb.com/video/?affiliateId=clubMEGAMENU" data-phone-href="http://m.mlb.com/video/?affiliateId=clubMEGAMENU">Video<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--media-panel" data-title="Video">
# <h2 class="panel__title">Video</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--recent-media">
# <h2 class="module__title">Video</h2>
# <ul>
# </ul></div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">In This Section</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mediacenter/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU" data-phone-href="">
# Watch / Listen
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/?topic_id=63817564" data-phone-href="http://m.mlb.com/video/?topic_id=63817564">
# Instant Replay
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/73955164" data-phone-href="http://m.mlb.com/video/topic/73955164">
# Statcast
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/network" data-phone-href="http://m.mlb.com/network">
# MLB Network
# </a>
# </li>
# <li>
# <a href="http://www.120sports.com/" data-phone-href="">
# 120 Sports
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/audio/podcast/?tcid=mm_mlb_vid" data-phone-href="">
# Podcasts
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/media/player/mpa/index.jsp?c_id=mlb&amp;affiliateId=mlbMENUACCESSIBLEGDA&amp;tcid=mm_mlb_vid" data-phone-href="">
# Alternative Audio
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/11493214" data-phone-href="http://m.mlb.com/video/topic/11493214">
# Must C
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/?tcid=mm_mlb_vid" data-phone-href="http://m.mlb.com/video/?tcid=mm_mlb_vid">
# Most Popular
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/video/play.jsp?topic_id=7759164&amp;tcid=mm_mlb_vid" data-phone-href="">
# Baseball's Best Moments
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/help/faq_index.jsp?tcid=mm_mlb_vid" data-phone-href="">
# FAQs
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/video/mlb_productions/?tcid=mm_mlb_vid" data-phone-href="">
# MLB Productions
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/help/supportforum/index.jsp?tcid=mm_mlb_vid" data-phone-href="">
# MLB.com Support Forum
# </a>
# </li>
# <li>
# <a href="http://web.getgreat.com/index.jsp" data-phone-href="">
# GetGreat.com
# </a>
# </li>
# </ul>
# </div>
# <div class="panel__module panel__module--related-links">
# <h2 class="module__title">Featured</h2>
# <ul class="link__list">
# <li>
# <a href="http://m.mlb.com/video/topic/39049312/" data-phone-href="http://m.mlb.com/video/topic/39049312">2015 Postseason</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/40172882/" data-phone-href="http://m.mlb.com/video/topic/40172882/">MLB.com Hot Stove</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/63371196/" data-phone-href="http://m.mlb.com/video/topic/63371196/">MLB Awards</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/11493214" data-phone-href="http://m.mlb.com/video/topic/11493214">Must C</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/33026172" data-phone-href="http://m.mlb.com/video/topic/33026172">Chatting Cage</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/61827086" data-phone-href="http://m.mlb.com/video/topic/61827086">Bud Celebrations</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/9674738" data-phone-href="http://m.mlb.com/video/topic/9674738">FastCast</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/7617858" data-phone-href="http://m.mlb.com/video/topic/7617858">AFL</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/51231442" data-phone-href="http://m.mlb.com/video/topic/51231442">Outstandings</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/21753540/" data-phone-href="http://m.mlb.com/video/topic/21753540/">Cut 4</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/17392054/" data-phone-href="http://m.mlb.com/video/topic/17392054/">Daily Dash</a>
# </li>
# <li>
# <a href="http://m.mlb.com/video/topic/11493214/" data-phone-href="http://m.mlb.com/video/topic/11493214/">Must C</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--stats" data-wired-order="4">
# <a class="menu-item--link" href="http://mlb.mlb.com/stats/sortable.jsp" data-phone-href="http://m.mlb.com/stats">Stats<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Stats</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Stats</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/stats/sortable.jsp" data-phone-href="http://m.mlb.com/stats">
# Postseason Sortable Stats
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/stats/sortable.jsp#elem=%5Bobject+Object%5D&amp;tab_level=child&amp;click_text=Sortable+Player+hitting&amp;game_type=&#39;R&#39;&amp;season=2015&amp;season_type=ANY&amp;league_code=&#39;MLB&#39;&amp;sectionType=sp&amp;statType=hitting&amp;page=1&amp;ts=1443450737345&amp;timeframe=" data-phone-href="http://m.mlb.com/stats/?stat_type=hitting&amp;season=2015&amp;game_type=R&amp;sort_column=avg&amp;player_pool=QUALIFIER">
# Regular Season Sortable Player Stats
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/stats/league_leaders.jsp" data-phone-href="">
# Regular Season League Leaders
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/statcast/leaderboard" data-phone-href="http://m.mlb.com/statcast/leaderboard">
# Statcast Leaders
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/stats/sortable.jsp#elem=%5Bobject+Object%5D&amp;tab_level=child&amp;click_text=Sortable+Team+hitting&amp;game_type=&#39;R&#39;&amp;season=2015&amp;season_type=ANY&amp;league_code=&#39;MLB&#39;&amp;sectionType=st&amp;statType=hitting&amp;page=1&amp;ts=1429812522958" data-phone-href="">
# Sortable Team Stats
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/stats/milestone_tracker.jsp" data-phone-href="">
# Milestone Tracker
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/milb/stats/?tcid=mm_mlb_stats" data-phone-href="">
# Offseason Leagues
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/promo/scoring-changes" data-phone-href="http://m.mlb.com/promo/scoring-changes">
# Scoring Changes
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/glossary" data-phone-href="http://m.mlb.com/glossary">
# Glossary
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/stats/sortable.jsp?c_id=mlb&amp;tcid=mm_mlb_stats#elem=[object+Object]&amp;tab_level=child&amp;click_text=Sortable+Player+hitting&amp;sectionType=sp&amp;statType=hitting&amp;page=1&amp;ts=1362435389667" data-phone-href="">
# <img data-src="/images/4/5/2/42261452/160x160_sortable_stats_j3b0337b.jpg" />
# <span>Sortable Stats</span>
# </a></div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--standings" data-wired-order="5">
# <a class="menu-item--link" href="http://mlb.mlb.com/mlb/standings/index.jsp" data-phone-href="http://m.mlb.com/standings">Standings<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Standings</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Standings</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mlb/standings/index.jsp?tcid=mm_mlb_standings" data-phone-href="http://m.mlb.com/standings/?yyyy=2015&amp;view=divisional">
# Regular Season Standings
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/standings/wildcard.jsp?tcid=mm_mlb_standings" data-phone-href="http://m.mlb.com/standings/?view=wildcard">
# Wild Card Standings
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/standings/probability.jsp" data-phone-href="">
# Postseason Probabilities
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/standings/postseason-picture/" data-phone-href="http://mlb.mlb.com/mlb/standings/postseason-picture/">
# Postseason Picture
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/standings/exhibition.jsp?tcid=mm_mlb_standings" data-phone-href="http://m.mlb.com/standings/?yyyy=2015&amp;view=spring">
# Spring Training Standings
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/news/article/59527184/playoff-tiebreaker-rules" data-phone-href="http://m.mlb.com/news/article/59527184/playoff-tiebreaker-rules">
# Tiebreaker rules
# </a>
# </li>
# </ul>
# </div> </div>
# </div>
# </li>
# <li class="menu-item menu-item--schedule" data-wired-order="6">
# <a class="menu-item--link" href="http://mlb.mlb.com/mlb/schedule/index.jsp#date=04/03/2016" data-phone-href="http://m.mlb.com/schedule/2016/04/03/?season=2016">Schedule<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Schedule</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Schedule</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mlb/schedule/index.jsp#date=02/28/2016" data-phone-href="http://m.mlb.com/schedule/2016/02/28">
# 2016 Spring Training
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/news/article/161611184/" data-phone-href="http://m.mlb.com/news/article/161611184/">
# Spring Training Workout Dates
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/schedule/index.jsp#date=04/03/2016" data-phone-href="http://m.mlb.com/schedule/2016/04/03/">
# 2016 Regular Season
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/postseason-schedule" data-phone-href="http://m.mlb.com/postseason-schedule">
# 2015 Postseason
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/schedule/events#Important_Dates" data-phone-href="http://m.mlb.com/schedule/events#Important_Dates">
# Important Dates
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/schedule/team_by_team.jsp?tcid=mm_mlb_schedule" data-phone-href="">
# Team-by-Team Schedule
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/official_info/broadcasts/national.jsp?tcid=mm_mlb_schedule" data-phone-href="">
# National Broadcasts
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/news/probable_pitchers/?tcid=nav_mlb_schedule" data-phone-href="">
# Probable Pitchers
# </a>
# </li>
# <li>
# <a href="http://www.match.com/cpx/en-us/partner/mlb/channel/?trackingid=530606&amp;bannerid=3865466" data-phone-href="http://www.match.com/cpx/en-us/partner/mlb/channel/?trackingid=530606&amp;bannerid=3865466">
# MLB Singles
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--promotional-image">
# <a href="http://www.match.com/cpx/en-us/partner/mlb/channel/?trackingid=528720&amp;bannerid=2813852" data-phone-href="http://www.match.com/cpx/en-us/partner/mlb/channel/?trackingid=528720&amp;bannerid=2813852">
# <img data-src="/images/8/0/4/141535804/160x160_MLB_match_un6qj9jq.jpg" />
# <span></span>
# </a></div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--players" data-wired-order="7">
# <a class="menu-item--link" href="http://mlb.mlb.com/mlb/players/?tcid=nav_mlb_players" data-phone-href="">Players<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Players</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Players</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mlb/players/?tcid=mm_mlb_players" data-phone-href="">
# Player Search
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/wsfb/news/injuries.jsp?tcid=mm_mlb_players" data-phone-href="">
# Injury Updates
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/team/depth_chart/index.jsp?c_id=ana&amp;tcid=mm_mlb_players" data-phone-href="">
# Depth Charts
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/transactions/?tcid=mm_mlb_players" data-phone-href="">
# Transactions
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/prospects/2016" data-phone-href="http://m.mlb.com/prospects/2016">
# Top Prospects
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/news/hot_stove/y2015/free_agent_tracker.jsp" data-phone-href="http://m.mlb.com/hotstove">
# Hot Stove Tracker
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mobile/text.jsp?tcid=mm_mlb_players" data-phone-href="">
# Mobile Player Alerts
# </a>
# </li>
# <li>
# <a href="http://mlbplayers.mlb.com/pa/index.jsp?tcid=mm_mlb_players" data-phone-href="">
# MLB Players Association
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/news/probable_pitchers/?tcid=nav_mlb_players" data-phone-href="">
# Probable Pitchers
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/events/all_star/y2015/franchise_four.jsp" data-phone-href="http://mlb.mlb.com/mlb/events/all_star/y2015/franchise_four.jsp">
# Franchise Four
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/mlb/news/hot_stove/y2015/free_agent_tracker.jsp" data-phone-href="http://m.mlb.com/hotstove">
# <img data-src="/images/5/1/4/156290514/160x160_HotStove_tracker_40zme9iw.jpg" />
# <span>Hot Stove Tracker</span>
# </a></div>
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlbdigitalacademy.com/coaches_corner" data-phone-href="">
# <img data-src="/images/5/9/0/56857590/MLB_com_160x160_c6a49dox_34082928.jpg" />
# <span></span>
# </a></div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--tickets" data-wired-order="8">
# <a class="menu-item--link" href="http://mlb.mlb.com/mlb/tickets/?tcid=nav_mlb_tickets&amp;y=2015" data-phone-href="http://m.mlb.com/tickets">Tickets<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Tickets</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Tickets</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mlb/tickets/?tcid=mm_mlb_tickets" data-phone-href="http://m.mlb.com/tickets">
# General Ticket Information
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/tickets/ps_refund_2015.jsp" data-phone-href="">
# Postseason Ticket Refund Policies
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/sh" data-phone-href="">
# StubHub.com
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/mlb/schedule/index.jsp?affiliateId=31HG1EK3481-210X" data-phone-href="http://mlb.mlb.com/mlb/schedule/index.jsp?affiliateId=31HG1EK3481-210X">
# <img data-src="/images/6/8/4/152114684/160x160_2016Schedule_uz5lemc4.jpg" />
# <span>2016 Schedule</span>
# </a></div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--mobile" data-wired-order="9">
# <a class="menu-item--link" href="http://mlb.mlb.com/mobile/?tcid=nav_mlb_mobile" data-phone-href="http://m.mlb.com/apps/">Apps<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Apps</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Apps</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mobile/atbat/" data-phone-href="http://m.mlb.com/apps/atbat">
# At Bat app
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mobile/tablets/" data-phone-href="">
# At Bat on Tablets
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mobile/ipad/" data-phone-href="">
# At Bat on Apple iPad&reg;
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mobile/ballpark/" data-phone-href="http://m.mlb.com/apps/ballpark/">
# MLB.com Ballpark app
# </a>
# </li>
# <li>
# <a href="http://hyperurl.co/mlbfans?IQid=MLB.HT73" data-phone-href="http://hyperurl.co/mlbfans?IQid=MLB.HT73">
# MLB Fans App
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/bts/y2014/splash_index.jsp" data-phone-href="">
# Beat the Streak
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/hr_derby/index.jsp" data-phone-href="">
# MLB.com Home Run Derby
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/linedrive/index.jsp" data-phone-href="">
# MLB.com Line Drive
# </a>
# </li>
# <li>
# <a href="http://www.rbigame.com" data-phone-href="http://www.rbigame.com">
# RBI Baseball 15
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/ballpark_empire/index.jsp" data-phone-href="">
# MLB Ballpark Empire
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/fantasy/franchisemvp/index.jsp" data-phone-href="">
# MLB.com Franchise MVP
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mobile/dashboard.jsp" data-phone-href="">
# Mobile Dashboard
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/help/faq_alerts.jsp?c_id=mlb" data-phone-href="">
# FAQ
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/mobile/atbat/index.jsp" data-phone-href="">
# <img data-src="/images/2/2/2/16724222/160x160_867xl1k6.jpg" />
# <span></span>
# </a></div>
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/mobile/attheballpark/index.jsp?c_id=mlb" data-phone-href="">
# <img data-src="/images/2/5/8/21249258/Ballpark_160x160_i7h1ouix.jpeg" />
# <span></span>
# </a></div>
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/mlb/fantasy/linedrive/index.jsp" data-phone-href="">
# <img data-src="/images/6/3/4/157967634/LD_160x160_ai0segw9.jpg" />
# <span>MLB.com Line Drive</span>
# </a></div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--shop" data-wired-order="10">
# <a class="menu-item--link" href="http://shop.mlb.com/?partnerId=X23M1TV388R1-10" data-phone-href="http://mshop.mlb.com/?partnerId=X23M1TV388R1-10">Shop<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">Shop</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">Shop</h2>
# <ul class="link__list">
# <li>
# <a href="http://shop.mlb.com/Jerseys?partnerId=3R13Z8L8G1-72" data-phone-href="http://mshop.mlb.com/Jerseys?partnerId=3R13Z8L8G1-72">
# Jerseys
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Caps?partnerId=1O713IUD881-134G" data-phone-href="http://mshop.mlb.com/Caps?partnerId=1O713IUD881-134G">
# Caps
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Men?partnerId=1A1P13881P-Z196J" data-phone-href="http://mshop.mlb.com/Men?partnerId=1A1P13881P-Z196J">
# Men's
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Women?partnerId=31392YM1BX-5" data-phone-href="http://mshop.mlb.com/Women?partnerId=31392YM1BX-5">
# Women's
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Kids?partnerId=V311JP3931IA-16" data-phone-href="http://mshop.mlb.com/Kids?partnerId=V311JP3931IA-16">
# Kids
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Big_And_Tall?partnerId=2F9G13H9P31-7D6" data-phone-href="http://mshop.mlb.com/Big_And_Tall?partnerId=2F9G13H9P31-7D6">
# Big & Tall
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Collectibles_And_Memorabilia?partnerId=CK1313Q931B-1T43" data-phone-href="http://mshop.mlb.com/Collectibles_And_Memorabilia?partnerId=CK1313Q931B-1T43">
# Collectibles & Memorabilia
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/Home_And_Office?partnerId=51P39TAH31-20L5" data-phone-href="http://mshop.mlb.com/Home_And_Office?partnerId=51P39TAH31-20L5">
# Home &amp; Office
# </a>
# </li>
# <li>
# <a href="http://shop.mlb.com/on_sale/yes?partnerId=31ER13931S-33D1A" data-phone-href="http://mshop.mlb.com/on_sale/yes?partnerId=31ER13931S-33D1A">
# Clearance
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--related-links">
# <h2 class="module__title">Auctions</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mlb/authentication/index.jsp" data-phone-href="">Authentication</a>
# </li>
# <li>
# <a href="http://www.baseballcards.mlb.com" data-phone-href="">Baseball Cards</a>
# </li>
# <li>
# <a href="http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&amp;rc=25&amp;selectedCatId=13020&amp;sort=timeleft_asc&amp;pgmode2=catpage" data-phone-href="">Baseballs</a>
# </li>
# <li>
# <a href="http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&amp;rc=25&amp;selectedCatId=13021&amp;sort=timeleft_asc&amp;pgmode2=catpage" data-phone-href="">Caps</a>
# </li>
# <li>
# <a href="http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&amp;rc=25&amp;selectedCatId=13060&amp;sort=timeleft_asc&amp;pgmode2=catpage" data-phone-href="">Experiences</a>
# </li>
# <li>
# <a href="http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&amp;rc=25&amp;selectedCatId=13062&amp;sort=timeleft_asc&amp;pgmode2=catpage" data-phone-href="">Jerseys</a>
# </li>
# <li>
# <a href="http://auctions.mlb.com/iSynApp/allAuction.action?sid=1101001&amp;rc=25&amp;selectedCatId=13024&amp;sort=timeleft_asc&amp;pgmode2=catpage" data-phone-href="">Photos</a>
# </li>
# </ul>
# </div>
# <div class="panel__module panel__module--promotional-image">
# <a href="http://shop.mlb.com/Custom_Shop?partnerId=LJ1I114M051-A17" data-phone-href="http://.shop.mlb.com/Custom_Shop?partnerId=LJ1I114M051-A17">
# <img data-src="/images/9/9/2/164723992/160x166_Tray_CustomShop2_3xm6gn8d.jpg" />
# <span>Custom Shop</span>
# </a></div>
# <div class="panel__module panel__module--promotional-image">
# <a href="http://auction.mlb.com/" data-phone-href="">
# <img data-src="/images/6/3/0/163475630/160x160_MLB_Auctions_cv6d8fn5.jpg" />
# <span>MLB Auctions</span>
# </a></div>
# </div>
# </div>
# </li>
# <li class="menu-item menu-item--mlbtv" data-wired-order="11">
# <a class="menu-item--link" href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU" data-phone-href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU">MLB.TV<div class="submenu-button"></div></a>
# <div class="menu__submenu panel panel--generic-panel">
# <h2 class="panel__title">MLB.TV</h2>
# <div class="panel__container panel__container--a">
# <div class="panel__module panel__module--in-this-section">
# <h2 class="module__title">MLB.TV</h2>
# <ul class="link__list">
# <li>
# <a href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU" data-phone-href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU">
# Buy MLB.TV
# </a>
# </li>
# <li>
# <a href="http://m.mlb.com/scoreboard" data-phone-href="">
# Watch/Listen
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/media/player/mpa/index.jsp?c_id=mlb&amp;affiliateId=mlbMENUACCESSIBLEGDA&amp;tcid=mm_mlb_vid" data-phone-href="">
# Alternative Audio
# </a>
# </li>
# <li>
# <a href="https://secure.mlb.com/tv/activate/?&amp;affiliateId=mlbMENU" data-phone-href="">
# MLB.TV with Extra Innings
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?content=products&amp;c_id=mlb&amp;affiliateId=mlbMENU" data-phone-href="">
# MLB.TV Devices
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/help/faq_index.jsp?tcid=mm_mlb_vid" data-phone-href="">
# FAQs
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/help/supportforum/index.jsp?tcid=mm_mlb_vid" data-phone-href="">
# MLB.com Support Forum
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU#blackout_header" data-phone-href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU#blackout_header">
# MLB.TV Blackouts
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/subscriptions/download.jsp?&amp;affiliateId=mlbMENU" data-phone-href="">
# MLB.TV Download Center
# </a>
# </li>
# <li>
# <a href="http://mlb.mlb.com/mlb/help/contact_us.jsp?&amp;affiliateId=mlbMENU" data-phone-href="http://m.mlb.com/help/contact/">
# Contact Us
# </a>
# </li>
# </ul>
# </div> </div>
# <div class="panel__container panel__container--b">
# <div class="panel__module panel__module--promotional-image">
# <a href="http://mlb.mlb.com/mlb/subscriptions/index.jsp?c_id=mlb&amp;affiliateId=mlbMENU" data-phone-href="">
# <img data-src="/images/4/7/0/164415470/160x160_MLBTV2016_det_akcoxxdx.jpg" />
# <span></span>
# </a></div>
# <div class="panel__module panel__module--promotional-image">
# ...
# <li><a data-phone-href="http://m.mlb.com/help/notices/" href="http://mlb.mlb.com/mlb/official_info/about_mlb_com/legal_notices.jsp">Legal Notices</a></li>
# <li><a data-phone-href="http://m.mlb.com/help/contact/" href="http://mlb.mlb.com/mlb/help/contact_us.jsp">Contact Us</a></li>
# </ul>
# <div id="copyright-container">&#169; <span class="copyright-year"></span> MLB Advanced Media, LP. All rights reserved.</div>
# </div>
# <ul id="footer-language-links">
# <li><a href="http://www.mlb.com" target="_blank" title="MLB in English">View MLB.com in English</a></li>
# <li><a href="http://LasMayores.com" target="_blank" title="MLB en Espa&ntilde;ol">En Espa&ntilde;ol</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </section>
# </div>
# <div id="mobile-interstitial">
# <div class="interstitial-mask"></div>
# <div class='promo'>
# <span class="close"></span>
# </div>
# </div>
# <!-- test jenkins file move-->
# <!-- ###################################################### -->
# <script type="text/javascript">
# // config settings
# var mlbSettings = {
# deviceType : DeviceType.device,
# override : 'desktop',
# startup : 'desktop',
# hostname: "http://ui.bamstatic.com/",
# sourceDirectory : "deploy/4.2.1"
# };
# if (mlbSettings.deviceType === 'phone' || mlbSettings.override === 'phone') {
# mlbSettings.startup = 'phone'
# } else if (mlbSettings.deviceType === 'tablet' || mlbSettings.override === 'tablet') {
# mlbSettings.startup = 'tablet'
# }
# </script>
# <script src="http://mlb.mlb.com/bundle?js=http://ui.bamstatic.com//bridge/core/shims/string.js&js=http://ui.bamstatic.com//bridge/core/shims/date.js&js=http://ui.bamstatic.com//bridge/core/require/require.js&js=http://ui.bamstatic.com//bridge/core/jquery/jquery.min.js&js=http://ui.bamstatic.com//clubs/mlb/startup/requireConfigs.js&v=4.2.1"></script>
# <script type="text/javascript">
# // need to add this shim for other browsers that dont support local storage - ugly but should only imapct a small set of browsers and that pos kisok downstairs
# if (typeof(localStorage) == 'undefined' ) {
# document.write('<script src="http://ui.bamstatic.com//bridge/core/shims/ie7/localStorage.js" type="text/javascript"><\/script>');
# document.write('<script src="http://ui.bamstatic.com//bridge/core/shims/ie8/es5shim.js" type="text/javascript"><\/script>');
# }
# </script>
# <!-- Safari < 5.1.7 -->
# <script type="text/javascript">
# if(!Function.prototype.bind){
# Function.prototype.bind = function(){
# [].unshift.call(arguments, this);
# return $.proxy.apply($,arguments);
# }
# }
# </script>
# <!-- ###################################################### -->
# <script type="text/javascript">
# // load device specific startup modules
# define('loadForDevice',['require'],function(require) {
# require(['http://ui.bamstatic.com//clubs/mlb/startup/deploy/4.2.1/'+ mlbSettings.startup +'/mlbStartup.js','http://ui.bamstatic.com//fedapp/headers/builds/1.0.1/scripts/header.js','http://ui.bamstatic.com//fedapp/footers/builds/0.0.0/scripts/footer.js'], function () {
# !function(){var a=!0;!function(b,c,d,e,f){!function(a){if("function"==typeof require&&"object"==typeof exports&&"object"==typeof module){var c=module.exports||exports;a(c)}else"function"==typeof define&&define.amd?define("bridge/lib/knockout-2.2.0",["exports"],a):a(b.ko={})}(function(g){function h(a){var b=this;if(a)for(var c in a){var d=l.extenders[c];"function"==typeof d&&(b=d(b,a[c]))}return b}function i(a){l.bindingHandlers[a]={init:function(b,c,d,e){var f=function(){var b={};return b[a]=c(),b};return l.bindingHandlers.event.init.call(this,b,f,d,e)}}}function j(a,b,c,d){l.bindingHandlers[a]={init:function(a){return l.utils.domData.set(a,t,{}),{controlsDescendantBindings:!0}},update:function(a,e,f,g,h){var i=l.utils.domData.get(a,t),j=l.utils.unwrapObservable(e()),k=!c!=!j,m=!i.savedNodes,n=m||b||k!==i.didDisplayOnLastUpdate;n&&(m&&(i.savedNodes=l.utils.cloneNodes(l.virtualElements.childNodes(a),!0)),k?(m||l.virtualElements.setDomNodeChildren(a,l.utils.cloneNodes(i.savedNodes)),l.applyBindingsToDescendants(d?d(h,j):h,a)):l.virtualElements.emptyNode(a),i.didDisplayOnLastUpdate=k)}},l.expressionRewriting.bindingRewriteValidators[a]=!1,l.virtualElements.allowedBindings[a]=!0}function k(a,b,c){c&&b!==l.selectExtensions.readValue(a)&&l.selectExtensions.writeValue(a,b),b!==l.selectExtensions.readValue(a)&&l.dependencyDetection.ignore(l.utils.triggerEvent,null,[a,"change"])}var l="undefined"!=typeof g?g:{};l.exportSymbol=function(a,b){for(var c=a.split("."),d=l,e=0;e<c.length-1;e++)d=d[c[e]];d[c[c.length-1]]=b},l.exportProperty=function(a,b,c){a[b]=c},l.version="2.2.1",l.exportSymbol("version",l.version),l.utils=new function(){function a(a,b){if("input"!==l.utils.tagNameLower(a)||!a.type)return!1;if("click"!=b.toLowerCase())return!1;var c=a.type;return"checkbox"==c||"radio"==c}var g=/^(\s|\u00A0)+|(\s|\u00A0)+$/g,h={},i={},j=/Firefox\/2/i.test(d.userAgent)?"KeyboardEvent":"UIEvents";h[j]=["keyup","keydown","keypress"],h.MouseEvents=["click","dblclick","mousedown","mouseup","mousemove","mouseover","mouseout","mouseenter","mouseleave"];for(var k in h){var m=h[k];if(m.length)for(var n=0,o=m.length;o>n;n++)i[m[n]]=k}var p={propertychange:!0},q=function(){for(var a=3,b=c.createElement("div"),d=b.getElementsByTagName("i");b.innerHTML="<!--[if gt IE "+ ++a+"]><i></i><![endif]-->",d[0];);return a>4?a:f}(),r=6===q,s=7===q;return{fieldsIncludedWithJsonPost:["authenticity_token",/^__RequestVerificationToken(_.*)?$/],arrayForEach:function(a,b){for(var c=0,d=a.length;d>c;c++)b(a[c])},arrayIndexOf:function(a,b){if("function"==typeof Array.prototype.indexOf)return Array.prototype.indexOf.call(a,b);for(var c=0,d=a.length;d>c;c++)if(a[c]===b)return c;return-1},arrayFirst:function(a,b,c){for(var d=0,e=a.length;e>d;d++)if(b.call(c,a[d]))return a[d];return null},arrayRemoveItem:function(a,b){var c=l.utils.arrayIndexOf(a,b);c>=0&&a.splice(c,1)},arrayGetDistinctValues:function(a){a=a||[];for(var b=[],c=0,d=a.length;d>c;c++)l.utils.arrayIndexOf(b,a[c])<0&&b.push(a[c]);return b},arrayMap:function(a,b){a=a||[];for(var c=[],d=0,e=a.length;e>d;d++)c.push(b(a[d]));return c},arrayFilter:function(a,b){a=a||[];for(var c=[],d=0,e=a.length;e>d;d++)b(a[d])&&c.push(a[d]);return c},arrayPushAll:function(a,b){if(b instanceof Array)a.push.apply(a,b);else for(var c=0,d=b.length;d>c;c++)a.push(b[c]);return a},extend:function(a,b){if(b)for(var c in b)b.hasOwnProperty(c)&&(a[c]=b[c]);return a},emptyDomNode:function(a){for(;a.firstChild;)l.removeNode(a.firstChild)},moveCleanedNodesToContainerElement:function(a){for(var b=l.utils.makeArray(a),d=c.createElement("div"),e=0,f=b.length;f>e;e++)d.appendChild(l.cleanNode(b[e]));return d},cloneNodes:function(a,b){for(var c=0,d=a.length,e=[];d>c;c++){var f=a[c].cloneNode(!0);e.push(b?l.cleanNode(f):f)}return e},setDomNodeChildren:function(a,b){if(l.utils.emptyDomNode(a),b)for(var c=0,d=b.length;d>c;c++)a.appendChild(b[c])},replaceDomNodes:function(a,b){var c=a.nodeType?[a]:a;if(c.length>0){for(var d=c[0],e=d.parentNode,f=0,g=b.leng ...
# j=p}}}k=2}if(2===k)for(var p in i){var q=l.bindingHandlers[p];if(q&&"function"==typeof q.update){var t=q.update;t(b,g(p),h,n,m)}}}},null,{disposeWhenNodeIsRemoved:b}),{shouldBindDescendants:j===f}}l.bindingHandlers={},l.bindingContext=function(a,b,c){b?(l.utils.extend(this,b),this.$parentContext=b,this.$parent=b.$data,this.$parents=(b.$parents||[]).slice(0),this.$parents.unshift(this.$parent)):(this.$parents=[],this.$root=a,this.ko=l),this.$data=a,c&&(this[c]=a)},l.bindingContext.prototype.createChildContext=function(a,b){return new l.bindingContext(a,this,b)},l.bindingContext.prototype.extend=function(a){var b=l.utils.extend(new l.bindingContext,this);return l.utils.extend(b,a)};var g="__ko_bindingContext__";l.storedBindingContextForNode=function(a,b){return 2!=arguments.length?l.utils.domData.get(a,g):(l.utils.domData.set(a,g,b),void 0)},l.applyBindingsToNode=function(a,b,c){return 1===a.nodeType&&l.virtualElements.normaliseVirtualElementDomStructure(a),e(a,b,c,!0)},l.applyBindingsToDescendants=function(a,b){(1===b.nodeType||8===b.nodeType)&&c(a,b,!0)},l.applyBindings=function(a,c){if(c&&1!==c.nodeType&&8!==c.nodeType)throw new Error("ko.applyBindings: first parameter should be your view model; second parameter should be a DOM node");c=c||b.document.body,d(a,c,!0)},l.contextFor=function(a){switch(a.nodeType){case 1:case 8:var b=l.storedBindingContextForNode(a);if(b)return b;if(a.parentNode)return l.contextFor(a.parentNode)}return f},l.dataFor=function(a){var b=l.contextFor(a);return b?b.$data:f},l.exportSymbol("bindingHandlers",l.bindingHandlers),l.exportSymbol("applyBindings",l.applyBindings),l.exportSymbol("applyBindingsToDescendants",l.applyBindingsToDescendants),l.exportSymbol("applyBindingsToNode",l.applyBindingsToNode),l.exportSymbol("contextFor",l.contextFor),l.exportSymbol("dataFor",l.dataFor)}();var q={"class":"className","for":"htmlFor"};l.bindingHandlers.attr={update:function(a,b){var c=l.utils.unwrapObservable(b())||{};for(var d in c)if("string"==typeof d){var e=l.utils.unwrapObservable(c[d]),g=e===!1||null===e||e===f;g&&a.removeAttribute(d),l.utils.ieVersion<=8&&d in q?(d=q[d],g?a.removeAttribute(d):a[d]=e):g||a.setAttribute(d,e.toString()),"name"===d&&l.utils.setElementName(a,g?"":e.toString())}}},l.bindingHandlers.checked={init:function(a,b,c){var d=function(){var d;if("checkbox"==a.type)d=a.checked;else{if("radio"!=a.type||!a.checked)return;d=a.value}var e=b(),f=l.utils.unwrapObservable(e);if("checkbox"==a.type&&f instanceof Array){var g=l.utils.arrayIndexOf(f,a.value);a.checked&&0>g?e.push(a.value):!a.checked&&g>=0&&e.splice(g,1)}else l.expressionRewriting.writeValueToProperty(e,c,"checked",d,!0)};l.utils.registerEventHandler(a,"click",d),"radio"!=a.type||a.name||l.bindingHandlers.uniqueName.init(a,function(){return!0})},update:function(a,b){var c=l.utils.unwrapObservable(b());"checkbox"==a.type?a.checked=c instanceof Array?l.utils.arrayIndexOf(c,a.value)>=0:c:"radio"==a.type&&(a.checked=a.value==c)}};var r="__ko__cssValue";l.bindingHandlers.css={update:function(a,b){var c=l.utils.unwrapObservable(b());if("object"==typeof c)for(var d in c){var e=l.utils.unwrapObservable(c[d]);l.utils.toggleDomNodeCssClass(a,d,e)}else c=String(c||""),l.utils.toggleDomNodeCssClass(a,a[r],!1),a[r]=c,l.utils.toggleDomNodeCssClass(a,c,!0)}},l.bindingHandlers.enable={update:function(a,b){var c=l.utils.unwrapObservable(b());c&&a.disabled?a.removeAttribute("disabled"):c||a.disabled||(a.disabled=!0)}},l.bindingHandlers.disable={update:function(a,b){l.bindingHandlers.enable.update(a,function(){return!l.utils.unwrapObservable(b())})}},l.bindingHandlers.event={init:function(a,b,c,d){var e=b()||{};for(var f in e)!function(){var e=f;"string"==typeof e&&l.utils.registerEventHandler(a,e,function(a){var f,g=b()[e];if(g){var h=c();try{var i=l.utils.makeArray(arguments);i.unshift(d),f=g.apply(d,i)}finally{f!==!0&&(a.preventDefault?a.preventDefault():a.returnValue=!1)}var j=h[e+"Bubble"]!==!1;j||(a.cancelBubble=!0,a.stopPropagation&&a.stopPropa ...
# //page specific - must be called startup
# require(['/sections/rhome/startup/deploy/4.3.2/'+ mlbSettings.startup +'/homeStartup.js'], function(){
# window.setOverlay = function (overlay) {
# $('<div id="background-overlay"></div>')
# .css({
# 'position' : 'absolute',
# 'top' : '200px',
# 'left' : '-130px',
# 'width' : '130px',
# 'z-index' : '1'
# })
# .html('<a href="' + overlay.clickHref + '" target="_blank"><img src="' + overlay.image + '" border="0" alt="" class="png" /></a>')
# .appendTo('#ad-skin');
# };
# window.setTakeover600 = function (container_id) {
# $('#'+container_id).find('iframe').css({
# 'height' : '600px'
# });
# $('#ad-lower').hide();
# };
# /*
# postseason tune in for wired and tablet
# */
# window.setTuneinTakeover = function (takeover) {
# require(['/sections/rhome/packages/postseason-tunein/postseason-tunein.js'], function (postSeasonTunein) {
# postSeasonTunein.init(takeover);
# });
# };
# require(['jquery'], function ($) {
# $(function(){
# $("#voices")
# .find("option[value$='matthew_leach']")
# .after("<option value='http://www.sportsonearth.com/writer/will_leitch'>Will Leitch</option>");
# /* Push Google objects and array */
# window.googletag = window.googletag || {};
# window.gptadslots = window.gptadslots || {};
# window.googletag.cmd = window.googletag.cmd || [];
# window.googletag.cmd.push(function() {
# window.googletag.pubads().enableAsyncRendering();
# window.googletag.pubads().collapseEmptyDivs();
# });
# /* stat-speed branding */
# $(".trending-item.stat-speed").each(function(i){
# var statSpeedAdId = "statSpeed-ad-" + i;
# $("<div/>")
# .attr("id",statSpeedAdId)
# .addClass("stat-speed-ad")
# .appendTo(this);
# window.googletag.cmd.push(function() {
# googletag.pubads().display('/2605/mlb.mlb/stat_speed', [145, 20], statSpeedAdId);
# });
# });
# /* player-tracking branding */
# $(".trending-item.player-tracking").each(function(i){
# var playerTrackingAdId = "playerTracking-ad-" + i;
# $("<div/>")
# .attr("id",playerTrackingAdId)
# .addClass("player-tracking-ad")
# .appendTo(this);
# window.googletag.cmd.push(function() {
# googletag.pubads().display('/2605/mlb.mlb/player_tracking', [145, 20], playerTrackingAdId);
# });
# });
# /* inject 250x25 ad in header */
# $('.device-desktop .languagebar .width-container').append($('<a>', {
# href: 'http://pubads.g.doubleclick.net/gampad/jump?iu=/2605/mlb.mlb/homepage&sz=250x25&t=pos%3D1&c=',
# css: {'right': '370px','float': 'right'},
# html: $('<img>', {
# src: 'http://pubads.g.doubleclick.net/gampad/ad?iu=/2605/mlb.mlb/homepage&sz=250x25&t=pos%3D1&c=',
# height: '25',
# width: '250'
# })
# }));
# });
# });
# });
# });
# });
# // load
# require(['loadForDevice']);
# </script>
# <script type="text/javascript">
# var _sf_async_config = {};
# _sf_async_config.uid = 43794;
# _sf_async_config.domain = 'mlb.com';
# _sf_async_config.sections = 'hp,index';
# _sf_async_config.authors = 'mlb';
# _sf_async_config.useCanonical = true;
# (function(){
# function loadChartbeat() {
# window._sf_endpt=(new Date()).getTime();
# var e = document.createElement('script');
# e.setAttribute('language', 'javascript');
# e.setAttribute('type', 'text/javascript');
# e.setAttribute('src', (('https:' == document.location.protocol) ? 'https://a248.e.akamai.net/chartbeat.download.akamai.com/102508/' : 'http://static.chartbeat.com/') + 'js/chartbeat.js');
# document.body.appendChild(e);
# }
# var oldonload = window.onload;
# window.onload = (typeof window.onload != 'function') ? loadChartbeat : function() { oldonload(); loadChartbeat(); };
# })();
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-TGJ9RZ"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TGJ9RZ');</script>
# <!-- End Google Tag Manager -->
# <!-- Begin BlueKai Tag -->
# <iframe name="__bkframe" height="0" width="0" frameborder="0" src="javascript:void(0)" style="width:1px;height:1px;position:absolute;bottom:0;"></iframe>
# <script type="text/javascript">
# if (DeviceType.device === "desktop") {
# document.write('<script src="//tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"><\/script>');
# document.write('<script src="http://mlb.mlb.com/scripts/tracking/bluekai.js" type="text/javascript"><\/script>');
# }
# </script>
# <!-- End BlueKai Tag -->
# <!-- ###################################################### -->
# <!-- Begin MyBuys Tag -->
# <script type="text/javascript" src="http://t.p.mybuys.com/js/mybuys4.js"></script>
# <script type="text/javascript" src="http://t.p.mybuys.com/clients/MLB/js/setup.js"></script>
# <script type="text/javascript">mybuys.setPageType("LANDING");</script>
# <script type="text/javascript">mybuys.initPage();</script>
# <!-- End MyBuys Tag -->
# </body>
# </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text)

# %%
h2 = soup.select('#sidebar-takeover-news')

# %%
for h in h2:
    print h.text
type(h)
# Out:
# Latest News
#
#
#
# Pujols might open 2016 on DL or as DH
# 2/18/2016 6:00 PM ET
#
#
#
#
# Wainwright enters spring feeling strong
# 2/18/2016 5:50 PM ET
#
#
#
#
#
#
#
# MLB.TV is back, better than ever
# 2/18/2016 9:47 AM ET
#
#
#
#
# Orange suits him: Cueto fitting in with Giants
# 2/18/2016 7:42 PM ET
#
#
#
#
#
#
#
# Chapman reports, will appeal if suspended
# 2/18/2016 1:18 PM ET
#
#
#
#
# Aviles' daughter cancer-free after transplant
# 2/18/2016 4:18 PM ET
#
#
#
#
# A-Gon confident LA will win NL West again
# 2/18/2016 2:52 PM ET
#
#
#
#
# Cards vs. Cubs tale of tape
# 2/18/2016 12:00 AM ET
#
# |
# Top fantasy 3B
# 2/18/2016 12:00 AM ET
#
# |
#
#
#
#
#
# More Headlines
#
#
# Follow @MLB
# bs4.element.Tag

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=3'
playload = {
'method':'search',
'searchMethod':'true',
'tenderUpdate':'',
'searchTarget':'',
'orgName':'',
'orgId':'',
'hid_1':'1',
'tenderName':'',
'tenderId':'',
'tenderType':'tenderDeclaration',
'tenderWay':'1,2,3,4,5,6,7,10,12',
'tenderDateRadio':'on',
'tenderStartDateStr':'105/02/13',
'tenderEndDateStr':'105/02/19',
'tenderStartDate':'105/02/19',
'tenderEndDate':'105/02/19',
'isSpdt':'N',
'proctrgCate':'3',
'radProctrgCate':'3',
'btnQuery':'查詢',
'hadUpdated':'',
}
res = requests.post(url,data=playload)

# %%
soup = BeautifulSoup(res.text)
trs = soup.select('tr')
for tr in trs:
    print tr.text.strip()
# Out:
# <!--
#   jQuery(document).ready(function(){
#     jQuery('td.homeevent').click(function() {
# 	  location.href = "/pis/index.jsp";
# 	});
#   });
# -->
#
# 回到首頁
#
# 回首頁
# :::  English ｜ 網站導覽 ｜ 意見信箱
# :::
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 電子公報
# 問題檢索
# 熱門問答集
# 請求協助
# 訂閱電子報
#
#
#
#
#
#
#
# 標案查詢
#
#
# 衛材藥品查詢
# 優先採購查詢
# 採購標的分類
# 採購預告查詢
# 公開閱覽查詢
# 公開徵求查詢
# 財物出租查詢
# 財物變賣查詢
# 物調公告查詢
# 外國廠商代碼
# 科技研究機構
# 效益評估查詢
# 連帶保證廠商
# 優良廠商名單
# 拒絕往來廠商
# 註銷拒絕往來廠商
# 全球化廠商名單
# 廠商綜合查詢
# 災區重建工程案件查詢
# 政治獻金法第七條查詢
# 得標外國政府採購案件查詢
# 臺灣銀行集中採購簡介
# 歷史文件瀏覽
#
#
#
#
#
#
#
# 全球政府採購商機
# 外國政府採購網站
#
#
#
#
#
#
#
# 代訓機構名單
# 代訓機構開課
# 採購法規題庫
#
#
#
#
#
#
#
#
# 巨額效益
#
#
#
#
#
#
#
#
# 招標文件範本
# 拒絕往來名單
# 系統使用手冊
# 2 代採購教材
# 颱風天等標期
# 共同供應契約
# 常用工具下載
# 資料集下載
# 重要訊息通告
# ５都改制文件
# 中央組改文件
#
#
#
#
#
#
#
# 政府憑證管理中心
# 工商憑證管理中心
# 自然人憑證管理中心
# 工程標案管理系統
# 工程不當延遲付款通報
# 促進民間參與公共建設公告
# 工程技師顧問公司系統
# 營建署全國建築管理資訊入口網
# 經濟部商工行政服務入口網
# 財政部稅務入口網
# 環保署節能標章綠色採購網
# 衛生福利部社會及家庭署身心障礙服務入口網
# 營建署工程重機械編管及運用管理系統
# 經濟部礦務局
# 承攬廠商公共工程履歷資料
# 內政部營建署營造業評鑑結果查詢
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ::: 首頁>標案查詢
#
#
#
#
#
#
#
#
#
# 標案查詢
#
#
#
#
#
#
#
# 註：◎ 檢視招標公告，請點選標案名稱或傳輸次數欄位下方之序號，如招標公告01
# ◎ 可檢視招標公告後，選擇電子領標按鈕
# ◎ 查詢結果依公告日期遞減排序,即最新公告之標案在最上方
#
#
#
#
#
#
#
#
#
#
#
#
#                         		document.write("<img src='/tps/images/print.jpg' alt='友善列印' width='16' height='16'><input name='button5' type='button' class='T11c' id='button5' value='友善列印' onClick='popWatermark2();print_doc();popWatermark();'>");
#
#
#
#
#
#
#
#
#
#
#
#
# 項次
# 機關 名稱
# 標案案號 標案名稱
# 傳輸 次數
# 招標 方式
# 採購 性質
# 公告 日期
# 截止 投標
# 預算 金額
#
#
#
# 1
#
# 空軍航空技術學院
#
#
# 												EG05042P039
#
#
#
# 建校80週年暨併校改制20週年校慶餐會
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														150000
#
#
#
#
#
#
#
#
# 2
#
# 台灣中油股份有限公司
#
#
# 												UAC048F001
#
#
#
# 石化事業部防漏零星修繕工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
# 3
#
# 經濟部中央地質調查所
#
#
# 												B10533
#
#
#
# 應用大規模崩塌活動性與發生度整合資訊於山崩與地滑地質敏感區劃定採購案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														4000000
#
#
#
#
#
#
#
#
# 4
#
# 雲林縣臺西鄉公所
#
#
# 												1050103
#
#
#
# 臺西鄉105年度移動式抽水機運輸操作委託勞務案(開口契約)
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														1121500
#
#
#
#
#
#
#
#
# 5
#
# 台灣電力股份有限公司台中區營業處
#
#
# 												1050500007
#
#
#
# 105年配電設備油漆彩繪、電桿牌裝掛勞務工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														2730000
#
#
#
#
#
#
#
#
# 6
#
# 屏東縣政府環境保護局
#
#
# 												1050005017-1
#
#
#
# 屏東縣東港溪及武洛溪畜牧糞尿農地肥分使用推動計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2808000
#
#
#
#
#
#
#
#
# 7
#
# 新北市新莊區公所
#
#
# 												1050204B2
#
#
#
# 新莊區公所各辦公廳舍消防設備定期保養維護
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														938205
#
#
#
#
#
#
#
#
# 8
#
# 臺北市政府工務局公園路燈工程管理處
#
#
# 												105C030
#
#
#
# 105年度陽明所暨花卉試驗中心所轄公園維護外包士林3號東和公園等委託維護管理服務
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/22
#
#
#
#
#
#
#
#
# 														8133671
#
#
#
#
#
#
#
#
# 9
#
# 國立成功大學醫學院附設醫院
#
#
# 												Y10504
#
#
#
# 放射免疫分析檢驗項目委外代檢
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														1713062
#
#
#
#
#
#
#
#
# 10
#
# 國立成功大學醫學院附設醫院
#
#
# 												Y10509
#
#
#
# 全院電腦周邊設備24小時維護工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														5900000
#
#
#
#
#
#
#
#
# 11
#
# 交通部航港局
#
#
# 												MPB10560219
#
#
#
# 「105年臺灣燈塔專輯設計、編輯、印刷」採購案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														1201000
#
#
#
#
#
#
#
#
# 12
#
# 交通部公路總局第四區養護工程處
#
#
# 												1054A002
#
#
#
# 代辦臺北榮民總醫院鳳林分院會客室及警衛室等復建工程委託設計及監造技術服務工作
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														1128728
#
#
#
#
#
#
#
#
# 13
#
# 臺北市政府環境保護局北投垃圾焚化廠
#
#
# 												PT1053013
#
#
#
# 105年度廠區環境清潔作業
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														1809516
#
#
#
#
#
#
#
#
# 14
#
# 台灣自來水股份有限公司第七區管理處
#
#
# 												W7-05-0701-50
#
#
#
# 105年度坪頂廠原水調節池清理
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														7560000
#
#
#
#
#
#
#
#
# 15
#
# 臺南市政府經濟發展局
#
#
# 												105ECON16S2
#
#
#
# 105年臺南市商圈輔導服務團計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														2000000
#
#
#
#
#
#
#
#
# 16
#
# 屏東縣政府環境保護局
#
#
# 												1050005017-2
#
#
#
# 105年度屏東縣水污染源稽查與水污費徵收查核計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2114000
#
#
#
#
#
#
#
#
# 17
#
# 台灣中油股份有限公司油品行銷事業部台北營業處
#
#
# 												DDK0521002
#
#
#
# 105~106年台北營業處地下儲槽系統管線密閉檢測
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														3787280
#
#
#
#
#
#
#
#
# 18
#
# 臺南市關廟區公所
#
#
# 												105021801
#
#
#
# 105年災後復建工程規劃設計（委託監造）開口契約
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														500000
#
#
#
#
#
#
#
#
# 19
#
# 新北市樹林區公所
#
#
# 												B105102
#
#
#
# 105年新北市垃圾處理場（廠）回饋金管理及運用委員會樹林區工作小組委員市政建設、文化、及環境自然生態觀摩參訪活動
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														220000
#
#
#
#
#
#
#
#
# 20
#
# 經濟部水利署第三河川局
#
#
# 												n1050130
#
#
#
# 105年度警告及宣導告示牌計畫
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/26
#
#
#
#
#
#
#
#
# 														1000000
#
#
#
#
#
#
#
#
# 21
#
# 高雄市政府地政局土地開發處
#
#
# 												1050215
#
#
#
# 「高雄市第94期市地重劃區(多功能經貿園區特貿5A)環境影響評估」委託技術服務案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/17
#
#
#
#
#
#
#
#
# 														5000000
#
#
#
#
#
#
#
#
# 22
#
# 台灣電力股份有限公司屏東區營業處
#
#
# 												1100571007
#
#
#
# 105年甲工區樹竹修剪工作
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														5460000
#
#
#
#
#
#
#
#
# 23
#
# 臺灣糖業股份有限公司工安環保處環保事業營運分處
#
#
# 												10500109
#
#
#
# 岡山廠105年度鍋爐歲修及大修等工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														18192014
#
#
#
#
#
#
#
#
# 24
#
# 高雄市政府水利局
#
#
# 												B1050130
#
#
#
# 中區污水處理廠、風車公園、壘球場環境清潔及維護
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														3100000
#
#
#
#
#
#
#
#
# 25
#
# 苗栗縣政府
#
#
# 												105018
#
#
#
# 苗栗縣政府消防局105年義消、協勤人員及其他救災民力投保1年期意外險採購案
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														1351500
#
#
#
#
#
#
#
#
# 26
#
# 臺南市安南區公所
#
#
# 												annan10502
#
#
#
# 臺南市安南區105年一般環境衛生消毒工作
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														510000
#
#
#
#
#
#
#
#
# 27
#
# 文化部
#
#
# 												10502172
#
#
#
# 文化部105年度「518國際博物館日」行銷推廣計畫勞務採購案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														2000000
#
#
#
#
#
#
#
#
# 28
#
# 國家災害防救科技中心
#
#
# 												NCDR-S-104054
#
#
#
# 災害訊息廣播平台系統-系統開發暨營運管理
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/07
#
#
#
#
#
#
#
#
# 														45000000
#
#
#
#
#
#
#
#
# 29
#
# 臺南市白河區公所
#
#
# 												105005
#
#
#
# 105年度白河區路燈維修勞務採購(開口契約)
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														1543000
#
#
#
#
#
#
#
#
# 30
#
# 行政院農業委員會
#
#
# 												105022P
#
#
#
# 105年度「資訊系統升級暨虛擬化擴充服務」採購
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														4048400
#
#
#
#
#
#
#
#
# 31
#
# 臺中市立神岡國民中學
#
#
# 												105001
#
#
#
# 臺中市立神岡國民中學105學年度三年級學生校外教學採購
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														1305000
#
#
#
#
#
#
#
#
# 32
#
# 雲林縣古坑鄉公所
#
#
# 												1050218-1
#
#
#
# 雲林縣古坑鄉105年度全鄉公墓雜草清除
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														1500000
#
#
#
#
#
#
#
#
# 33
#
# 台灣電力股份有限公司興達發電廠
#
#
# 												3410500040-S05019
#
#
#
# 興一機軸流式IDF大修工作
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/04
#
#
#
#
#
#
#
#
# 														8925000
#
#
#
#
#
#
#
#
# 34
#
# 福建省連江縣北竿鄉公所
#
#
# 												105A0121
#
#
#
# 105年度北竿鄉路燈委外維護工程（開口契約）
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														900000
#
#
#
#
#
#
#
#
# 35
#
# 國防部
#
#
# 												EY05008L034
#
#
#
# 電腦蒸餾儀等33項102年油化裝備維護案
#
#
#
#
#
#
#
#
#
#
# 04
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/26
#
#
#
#
#
#
#
#
# 														18180000
#
#
#
#
#
#
#
#
# 36
#
# 高雄市政府地政局土地開發處
#
#
# 												1050113
#
#
#
# 「高雄市前鎮區第205兵工廠區段徵收土地之公益性及必要性評估報告」委託專業服務案
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														2665950
#
#
#
#
#
#
#
#
# 37
#
# 新北市立永平高級中學
#
#
# 												YP105-004
#
#
#
# 105學年度9年級校外教學活動
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/04
#
#
#
#
#
#
#
#
# 														2288000
#
#
#
#
#
#
#
#
# 38
#
# 台灣電力股份有限公司大潭發電廠
#
#
# 												3800500006
#
#
#
# 105年度修配所屬機具保養暨檢修工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														1575000
#
#
#
#
#
#
#
#
# 39
#
# 台灣自來水股份有限公司第九區管理處
#
#
# 												WC-05-0900-25051103-01
#
#
#
# 105年度各淨水場水質監測儀器設備修護
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														677518
#
#
#
#
#
#
#
#
# 40
#
# 台灣自來水股份有限公司第一區管理處
#
#
# 												105036
#
#
#
# 105年度汐止所屆齡水表(含抽驗表)換裝委外承攬
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														1634756
#
#
#
#
#
#
#
#
# 41
#
# 臺北市政府環境保護局
#
#
# 												105S027
#
#
#
# 105年度「臺北市溝泥溝土再利用處理」
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														5760000
#
#
#
#
#
#
#
#
# 42
#
# 國立金門大學
#
#
# 												105NQU001
#
#
#
# 外籍生健康醫療保險(計五學期、詳規範)
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														1980000
#
#
#
#
#
#
#
#
# 43
#
# 高雄市政府水利局
#
#
# 												B1050126
#
#
#
# 高雄市政府水利局高壓沖洗車檢修保養
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														146055
#
#
#
#
#
#
#
#
# 44
#
# 臺北市立天文科學教育館
#
#
# 												105B5
#
#
#
# 2016飛向宇宙-太空旅行特展勞務採購案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														1800000
#
#
#
#
#
#
#
#
# 45
#
# 交通部公路總局新竹區監理所
#
#
# 												5010501
#
#
#
# 新竹區監理所交通違規案件清理作業勞務委外採購招標案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														245343
#
#
#
#
#
#
#
#
# 46
#
# 屏東縣政府
#
#
# 												143-1050203
#
#
#
# 「六塊厝水資源回收中心初沉池刮泥設施改善工程（第二期）」委託設計監造技術服務工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														960000
#
#
#
#
#
#
#
#
# 47
#
# 台灣中油股份有限公司
#
#
# 												AEC0513001
#
#
#
# 中油大樓資訊網路設備維護
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/09
#
#
#
#
#
#
#
#
# 														2900100
#
#
#
#
#
#
#
#
# 48
#
# 勞動部勞動及職業安全衛生研究所
#
#
# 												1052015
#
#
#
# 105年度職業安全衛生危害預防全國巡迴展示活動
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														6265259
#
#
#
#
#
#
#
#
# 49
#
# 行政院農業委員會林務局新竹林區管理處
#
#
# 												105B017-F17
#
#
#
# 105年度孝義苗圃苗木培養工作
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														4541063
#
#
#
#
#
#
#
#
# 50
#
# 屏東縣政府
#
#
# 												076-1050106
#
#
#
# 仁愛國小活動中心內部環境修繕工程委託規劃設計暨履約監造
#
#
#
#
#
#
#
#
#
#
# 04
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														263000
#
#
#
#
#
#
#
#
# 51
#
# 經濟部水利署第四河川局
#
#
# 												M105021501
#
#
#
# 濁水溪水系沿線綠美化場地
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														4196000
#
#
#
#
#
#
#
#
# 52
#
# 經濟部水利署南區水資源局
#
#
# 												105-C-01
#
#
#
# 曾文水庫取水斜塔前庭清淤工程-105年度第三公正單位清淤計量及檢驗監督工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														1350000
#
#
#
#
#
#
#
#
# 53
#
# 苗栗縣獅潭鄉公所
#
#
# 												105012905
#
#
#
# 105年獅潭鄉災害搶通搶險清淤清運開口契約（單價標）
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														1270000
#
#
#
#
#
#
#
#
# 54
#
# 基隆市環境保護局
#
#
# 												105KLEPB-G01
#
#
#
# 105年度基隆市加強街道揚塵洗掃計畫
#
#
#
#
#
#
#
#
#
#
# 06
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														7000000
#
#
#
#
#
#
#
#
# 55
#
# 臺中市政府水利局
#
#
# 												10501270020
#
#
#
# 105年度大甲區等7區災後水利復建工程委託設計監造技術服務開口契約
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2974100
#
#
#
#
#
#
#
#
# 56
#
# 臺北市政府環境保護局
#
#
# 												105S030
#
#
#
# 105年度「臺北市推動機關、學校資源回收工作計畫」
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														2200000
#
#
#
#
#
#
#
#
# 57
#
# 交通部公路總局
#
#
# 												105005
#
#
#
# 「Web版數位公路服務平台」建置(第2階段)
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														5000000
#
#
#
#
#
#
#
#
# 58
#
# 台灣電力股份有限公司新竹區營業處
#
#
# 												1040500002
#
#
#
# 105年工作停電通知單及事故停電致歉函分發工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														1260000
#
#
#
#
#
#
#
#
# 59
#
# 台灣自來水股份有限公司第一區管理處
#
#
# 												105028
#
#
#
# 105年度新山廠場站環境清理工作
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														1313130
#
#
#
#
#
#
#
#
# 60
#
# 屏東縣政府
#
#
# 												076-1050107
#
#
#
# 惠農國小玉水分校整建工程（供屏東菸場森警隊搬遷進駐使用）委託規劃設計暨履約監造
#
#
#
#
#
#
#
#
#
#
# 04
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														390000
#
#
#
#
#
#
#
#
# 61
#
# 高雄市立民生醫院
#
#
# 												KMMSH05005
#
#
#
# 105年度院舍環境清潔維護
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														5755217
#
#
#
#
#
#
#
#
# 62
#
# 臺北大眾捷運股份有限公司
#
#
# 												B05A00416
#
#
#
# 自動收費系統電腦設備維護工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/26
#
#
#
#
#
#
#
#
# 														7798980
#
#
#
#
#
#
#
#
# 63
#
# 金門縣環境保護局
#
#
# 												kepb105-02
#
#
#
# 金門縣105年度固定污染源許可管制及餐飲業污染輔導改善計畫
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														5700000
#
#
#
#
#
#
#
#
# 64
#
# 台灣電力股份有限公司第二核能發電廠
#
#
# 												3510500048
#
#
#
# 核二廠原生鳥類復育區植栽、綠化工作
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														1930000
#
#
#
#
#
#
#
#
# 65
#
# 新北市政府採購處
#
#
# 												1050304A
#
#
#
# 105年度新北市計程車駕駛人預防保健服務
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/04
#
#
#
#
#
#
#
#
# 														4640000
#
#
#
#
#
#
#
#
# 66
#
# 財團法人中華民國對外貿易發展協會
#
#
# 												10525000285
#
#
#
# 2016年台灣國際照明科技展電視廣告代理案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														382200
#
#
#
#
#
#
#
#
# 67
#
# 新竹縣政府環境保護局
#
#
# 												105-51
#
#
#
# 105年度新竹縣頭前溪流域生態治理區成效評估暨教育推廣計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2335000
#
#
#
#
#
#
#
#
# 68
#
# 高雄市立民生醫院
#
#
# 												KMMSH05009
#
#
#
# 105-108年度消化系內科醫師1名
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														9900000
#
#
#
#
#
#
#
#
# 69
#
# 新北市三峽區公所
#
#
# 												105Y008
#
#
#
# 105年三峽生命紀念館環境清潔維護案
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														483525
#
#
#
#
#
#
#
#
# 70
#
# 新北市政府文化局
#
#
# 												105A-015
#
#
#
# 105年度435藝文特區建物改善工程委託設計監造技術服務
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														164560
#
#
#
#
#
#
#
#
# 71
#
# 桃園市政府工務局
#
#
# 												1050127-1
#
#
#
# 桃園市政府105年員工上下班租用交通車
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														2916670
#
#
#
#
#
#
#
#
# 72
#
# 新北市立重慶國民中學
#
#
# 												C105002
#
#
#
# 105學年度八年級校外教學隔宿露營活動委託服務
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														1209450
#
#
#
#
#
#
#
#
# 73
#
# 台灣中油股份有限公司油品行銷事業部台中營業處
#
#
# 												DAC0541002
#
#
#
# 台中零售中心三民路加油站等15站勞務部分工時承攬工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														4924441
#
#
#
#
#
#
#
#
# 74
#
# 國防部軍備局生產製造中心
#
#
# 												JK05010P005
#
#
#
# AS9100品質管理系統建置輔導
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														280000
#
#
#
#
#
#
#
#
# 75
#
# 桃園大眾捷運股份有限公司
#
#
# 												1B05A640005
#
#
#
# 105年資訊設備維護案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														1247061
#
#
#
#
#
#
#
#
# 76
#
# 台灣中油股份有限公司油品行銷事業部台中營業處
#
#
# 												DAC0541001
#
#
#
# 台中零售中心進化路加油站等15站勞務部分工時承攬工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														4987617
#
#
#
#
#
#
#
#
# 77
#
# 桃園市立壽山高級中學
#
#
# 												SSSH10502
#
#
#
#  104學年度高二校外教學活動
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														3486570
#
#
#
#
#
#
#
#
# 78
#
# 臺灣銀行股份有限公司
#
#
# 												133-105-B032
#
#
#
# 「信用卡系統新增硬體亂碼化設備連線介面軟體｣採購案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2500000
#
#
#
#
#
#
#
#
# 79
#
# 台灣電力股份有限公司台中發電廠
#
#
# 												3710500049
#
#
#
# 軸承一批3項檢修
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														336000
#
#
#
#
#
#
#
#
# 80
#
# 台灣電力股份有限公司通霄發電廠
#
#
# 												3700500014
#
#
#
# 105年度ST4/5機海水取排水管檢查工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														9000000
#
#
#
#
#
#
#
#
# 81
#
# 臺北市中山區長春國民小學
#
#
# 												105B03
#
#
#
# 105年度圖書室整修暨仁愛樓遮陽設施改善工程委託規劃設計監造勞務採購
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														303364
#
#
#
#
#
#
#
#
# 82
#
# 臺灣糖業股份有限公司
#
#
# 												5803L1050217
#
#
#
# 台糖公司IBM AS/400主機軟硬體及IBM5400行列式印表機維護
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														2548000
#
#
#
#
#
#
#
#
# 83
#
# 高雄市苓雅區四維國民小學
#
#
# 												105-02
#
#
#
# 104學年度委託辦理幼兒課後留園服務
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														196800
#
#
#
#
#
#
#
#
# 84
#
# 行政院農業委員會林務局羅東林區管理處
#
#
# 												105-15-7
#
#
#
# 105年度國公有造林預定案第4、14、15、16、17號，新植及撫育等工作9.24公頃
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														1132372
#
#
#
#
#
#
#
#
# 85
#
# 行政院農業委員會林務局羅東林區管理處
#
#
# 												105-15-6
#
#
#
# 105年度國公有造林預定案第3、7、12號，營造複層林新植及撫育等工作19.57公頃
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														4453939
#
#
#
#
#
#
#
#
# 86
#
# 行政院農業委員會林務局羅東林區管理處
#
#
# 												105-15-5
#
#
#
# 105年度國公有造林預定案第2、10、11、13號，新植及撫育等工作26.46公頃
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														4823804
#
#
#
#
#
#
#
#
# 87
#
# 新北市立十三行博物館
#
#
# 												sshm105021701
#
#
#
# 十三行博物館休閒教育園區新建工程委託設計及監造技術服務
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/04
#
#
#
#
#
#
#
#
# 														3750000
#
#
#
#
#
#
#
#
# 88
#
# 臺北市市場處
#
#
# 												105W31
#
#
#
# 105年度公有環南市場環境衛生清潔維護
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														4852650
#
#
#
#
#
#
#
#
# 89
#
# 高雄市立民生醫院
#
#
# 												KMMSH05011
#
#
#
# 105-108年度胸腔內科醫師1名
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														9900000
#
#
#
#
#
#
#
#
# 90
#
# 內政部
#
#
# 												105JC0113
#
#
#
# 105年國民生活狀況意向調查
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/08
#
#
#
#
#
#
#
#
# 														1030000
#
#
#
#
#
#
#
#
# 91
#
# 澎湖縣政府環境保護局
#
#
# 												EP105009
#
#
#
# 105年度澎湖縣固定污染源稽查管制計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														3488000
#
#
#
#
#
#
#
#
# 92
#
# 國立臺灣大學醫學院附設醫院新竹分院
#
#
# 												1050101S
#
#
#
# 自動快速照相委外經營
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														0
#
#
#
#
#
#
#
#
# 93
#
# 臺北市松山區公所
#
#
# 												10404
#
#
#
# 105年度民有區民活動中心(含4、5樓)清潔維護
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														155250
#
#
#
#
#
#
#
#
# 94
#
# 交通部觀光局澎湖國家風景區管理處
#
#
# 												p-nsa104211
#
#
#
# 馬公、湖西遊憩系統設施工程委託設計監造案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/15
#
#
#
#
#
#
#
#
# 														4468500
#
#
#
#
#
#
#
#
# 95
#
# 高雄榮民總醫院
#
#
# 												SP-04374
#
#
#
# 急診檢驗室4項能力試驗試劑組
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														219000
#
#
#
#
#
#
#
#
# 96
#
# 臺南市政府水利局
#
#
# 												wat105020
#
#
#
# 105年度臺南市山坡地區水利設施搶修搶險、災害復建及減災工程測設監造開口契約
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/08
#
#
#
#
#
#
#
#
# 														5000000
#
#
#
#
#
#
#
#
# 97
#
# 國防部陸軍司令部
#
#
# 												GM05165P120
#
#
#
# 堆高機維修保養
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														1500000
#
#
#
#
#
#
#
#
# 98
#
# 臺北大眾捷運股份有限公司
#
#
# 												B05A00125
#
#
#
# 捷運系統營運階段環境監測工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														3197775
#
#
#
#
#
#
#
#
# 99
#
# 經濟部中央地質調查所
#
#
# 												B10529
#
#
#
# 臺灣北部火山地區地震與地球化學監測（1/2）採購案
#
#
#
#
#
# ...
#
#
# 105年度新竹縣頭前溪流域生態治理區成效評估暨教育推廣計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2335000
# 68
#
# 高雄市立民生醫院
#
#
# 												KMMSH05009
#
#
#
# 105-108年度消化系內科醫師1名
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														9900000
# 69
#
# 新北市三峽區公所
#
#
# 												105Y008
#
#
#
# 105年三峽生命紀念館環境清潔維護案
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														483525
# 70
#
# 新北市政府文化局
#
#
# 												105A-015
#
#
#
# 105年度435藝文特區建物改善工程委託設計監造技術服務
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														164560
# 71
#
# 桃園市政府工務局
#
#
# 												1050127-1
#
#
#
# 桃園市政府105年員工上下班租用交通車
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														2916670
# 72
#
# 新北市立重慶國民中學
#
#
# 												C105002
#
#
#
# 105學年度八年級校外教學隔宿露營活動委託服務
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														1209450
# 73
#
# 台灣中油股份有限公司油品行銷事業部台中營業處
#
#
# 												DAC0541002
#
#
#
# 台中零售中心三民路加油站等15站勞務部分工時承攬工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														4924441
# 74
#
# 國防部軍備局生產製造中心
#
#
# 												JK05010P005
#
#
#
# AS9100品質管理系統建置輔導
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														280000
# 75
#
# 桃園大眾捷運股份有限公司
#
#
# 												1B05A640005
#
#
#
# 105年資訊設備維護案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/03
#
#
#
#
#
#
#
#
# 														1247061
# 76
#
# 台灣中油股份有限公司油品行銷事業部台中營業處
#
#
# 												DAC0541001
#
#
#
# 台中零售中心進化路加油站等15站勞務部分工時承攬工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														4987617
# 77
#
# 桃園市立壽山高級中學
#
#
# 												SSSH10502
#
#
#
#  104學年度高二校外教學活動
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														3486570
# 78
#
# 臺灣銀行股份有限公司
#
#
# 												133-105-B032
#
#
#
# 「信用卡系統新增硬體亂碼化設備連線介面軟體｣採購案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														2500000
# 79
#
# 台灣電力股份有限公司台中發電廠
#
#
# 												3710500049
#
#
#
# 軸承一批3項檢修
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														336000
# 80
#
# 台灣電力股份有限公司通霄發電廠
#
#
# 												3700500014
#
#
#
# 105年度ST4/5機海水取排水管檢查工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														9000000
# 81
#
# 臺北市中山區長春國民小學
#
#
# 												105B03
#
#
#
# 105年度圖書室整修暨仁愛樓遮陽設施改善工程委託規劃設計監造勞務採購
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														303364
# 82
#
# 臺灣糖業股份有限公司
#
#
# 												5803L1050217
#
#
#
# 台糖公司IBM AS/400主機軟硬體及IBM5400行列式印表機維護
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														2548000
# 83
#
# 高雄市苓雅區四維國民小學
#
#
# 												105-02
#
#
#
# 104學年度委託辦理幼兒課後留園服務
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														196800
# 84
#
# 行政院農業委員會林務局羅東林區管理處
#
#
# 												105-15-7
#
#
#
# 105年度國公有造林預定案第4、14、15、16、17號，新植及撫育等工作9.24公頃
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														1132372
# 85
#
# 行政院農業委員會林務局羅東林區管理處
#
#
# 												105-15-6
#
#
#
# 105年度國公有造林預定案第3、7、12號，營造複層林新植及撫育等工作19.57公頃
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														4453939
# 86
#
# 行政院農業委員會林務局羅東林區管理處
#
#
# 												105-15-5
#
#
#
# 105年度國公有造林預定案第2、10、11、13號，新植及撫育等工作26.46公頃
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														4823804
# 87
#
# 新北市立十三行博物館
#
#
# 												sshm105021701
#
#
#
# 十三行博物館休閒教育園區新建工程委託設計及監造技術服務
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/04
#
#
#
#
#
#
#
#
# 														3750000
# 88
#
# 臺北市市場處
#
#
# 												105W31
#
#
#
# 105年度公有環南市場環境衛生清潔維護
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														4852650
# 89
#
# 高雄市立民生醫院
#
#
# 												KMMSH05011
#
#
#
# 105-108年度胸腔內科醫師1名
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														9900000
# 90
#
# 內政部
#
#
# 												105JC0113
#
#
#
# 105年國民生活狀況意向調查
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/08
#
#
#
#
#
#
#
#
# 														1030000
# 91
#
# 澎湖縣政府環境保護局
#
#
# 												EP105009
#
#
#
# 105年度澎湖縣固定污染源稽查管制計畫
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/02
#
#
#
#
#
#
#
#
# 														3488000
# 92
#
# 國立臺灣大學醫學院附設醫院新竹分院
#
#
# 												1050101S
#
#
#
# 自動快速照相委外經營
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														0
# 93
#
# 臺北市松山區公所
#
#
# 												10404
#
#
#
# 105年度民有區民活動中心(含4、5樓)清潔維護
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/25
#
#
#
#
#
#
#
#
# 														155250
# 94
#
# 交通部觀光局澎湖國家風景區管理處
#
#
# 												p-nsa104211
#
#
#
# 馬公、湖西遊憩系統設施工程委託設計監造案
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/15
#
#
#
#
#
#
#
#
# 														4468500
# 95
#
# 高雄榮民總醫院
#
#
# 												SP-04374
#
#
#
# 急診檢驗室4項能力試驗試劑組
#
#
#
#
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														219000
# 96
#
# 臺南市政府水利局
#
#
# 												wat105020
#
#
#
# 105年度臺南市山坡地區水利設施搶修搶險、災害復建及減災工程測設監造開口契約
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/08
#
#
#
#
#
#
#
#
# 														5000000
# 97
#
# 國防部陸軍司令部
#
#
# 												GM05165P120
#
#
#
# 堆高機維修保養
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														1500000
# 98
#
# 臺北大眾捷運股份有限公司
#
#
# 												B05A00125
#
#
#
# 捷運系統營運階段環境監測工作
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 公開招標
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/24
#
#
#
#
#
#
#
#
# 														3197775
# 99
#
# 經濟部中央地質調查所
#
#
# 												B10529
#
#
#
# 臺灣北部火山地區地震與地球化學監測（1/2）採購案
#
#
#
#
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 限制性招標(經公開評選或公開徵求)
#
# 勞務類
#
# 105/02/19
#
#
# 105/02/23
#
#
#
#
#
#
#
#
# 														6400000
# 100
#
# 臺北大眾捷運股份有限公司
#
#
# 												B05B00156
#
#
#
# 捷運車站及機廠污水設備銜接衛生下水道系統工程第五期委託規劃設計及監造技術服務工作
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 公開取得報價單或企劃書
#
# 勞務類
#
# 105/02/19
#
#
# 105/03/01
#
#
#
#
#
#
#
#
# 														624376
# [
# 								第一頁
# 							/
# 								上一頁
# 							]
#
#
#
# 									1
#
#
#
# 								,
#
#
# 									2
#
#
#
# 								,
# 								<3>
#
#
#
# 								,
#
#
# 									4
#
#
#
# 								,
#
#
# 									5
#
#
# 							 [
# 								下一頁
# 							/
# 								最後一頁
# 							] 共有477筆資料
#
# #qrcode_preview     {position:absolute; border:1px solid #000; background:#FFF; padding:15px; display:none; color:#666; font-size:11px; font-family:Tahoma; z-index:1000;}
#   #qrcode_preview img {margin:3px;}
#
#
#
# 	//var $jq = jQuery.noConflict();
#
#   function generateNowTime() {
# 	var time = new Date() ;
# 	var nowstr = time.getHours() + '點' + time.getMinutes() + '分';
# 	jQuery('strong.now_time').text(nowstr);
#   }
#
#   function getCounterValue(){
# 		jQuery.ajax({
# 					type: "POST",
# 					url: "/pis/ldapMenu.do?refresh=N",
# 					data: "method=getCounterValue",
# 					dataType: "html",
# 					timeout:30000,
# 					error: function(XMLHttpRequest, textStatus, errorThrown){
# 						if (textStatus == 'timeout'){
# 							// timeout
# 							jQuery('strong.counterValue').text('');
# 						}else{
# 							// error
# 							jQuery('strong.counterValue').text('error');
# 						}
# 						ajaxEvent = false;
# 					},
# 					beforeSend: function(){
# 						// busy
# 						ajaxEvent = true;
# 			   		},
# 			   		complete: function(){
# 			   			ajaxEvent = false;
# 			   		},
# 					success: function(doc){
# 						if(doc.toLowerCase){
# 							if(doc.toLowerCase().indexOf("</body>")!=-1){
# 								window.location.href="/pis";
# 							}else{
# 								jQuery('strong.counterValue').text(doc);
# 							}
# 						}
# 					}
# 				});
# 	}
#
#   jQuery(document).ready(function(){
# 	generateNowTime();
# 	setInterval("generateNowTime()", 60000);
#     if (jQuery.browser.msie) {
# 	  jQuery('#pcc_logo').css({'top': '-31px'});
# 	}
#
#     // 20110714 顯示訪客人數 added by David Tung
#     getCounterValue();
#
#   });
#
#
#
#
#
# :::
#
#
#
#
# 歡迎本區第
#
#  位訪客(至098/12/31累計76003935人次)　台灣時間為
#  11點17分
#
#
#
#
# 聯絡我們∥
# 	  		著作權聲明∥
# 	  		安全保護聲明∥
# 	  		個人隱私聲明∥
# 	  		無障礙聲明∥
# 	  		停機紀錄
#       	系統24小時免費客服電話：0800-080-512  客服傳真：0800-080-511
#       	工程會地址：臺北市信義區松仁路3號9樓  本會採購申訴審議委員會電話：(02)87897530
# 	  		中央採購稽核小組電話：(02)87897548  傳真：(02)87897554  下載Flash Player
# 	  		政府電子採購網  版權所有 © 2009  最後更新時間：99/02/25
# 	  		支援瀏覽器版本為IE6.0以上及Fire Fox3.0以上，解析度1024 X 768
#
#
#
# 			手機上網領標QR Code二維條碼
#
#
#
#
#
#
#
# Android
# iPhone
# iPad
#
#
#
#
# document.write("<tr><td align='center'><a target='_blank' href='http://www.webguide.nat.gov.tw/enable.jsp?category=20110613101339' title='無障礙網站'><img src='/pis/images/ap.jpg' border='0' width='88' height='31' alt='通過A+優先等級無障礙網頁檢測' /></a></td></tr>");
# :::
#
#
#
#
# 歡迎本區第
#
#  位訪客(至098/12/31累計76003935人次)　台灣時間為
#  11點17分
#
#
#
#
# 聯絡我們∥
# 	  		著作權聲明∥
# 	  		安全保護聲明∥
# 	  		個人隱私聲明∥
# 	  		無障礙聲明∥
# 	  		停機紀錄
#       	系統24小時免費客服電話：0800-080-512  客服傳真：0800-080-511
#       	工程會地址：臺北市信義區松仁路3號9樓  本會採購申訴審議委員會電話：(02)87897530
# 	  		中央採購稽核小組電話：(02)87897548  傳真：(02)87897554  下載Flash Player
# 	  		政府電子採購網  版權所有 © 2009  最後更新時間：99/02/25
# 	  		支援瀏覽器版本為IE6.0以上及Fire Fox3.0以上，解析度1024 X 768
#
#
#
# 			手機上網領標QR Code二維條碼
#
#
#
#
#
#
#
# Android
# iPhone
# iPad
#
# Android
# iPhone
# iPad

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex={}'
for i in xrange(0,5):
    print i
    print url.format(i+1)
# Out:
# 0
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=1
# 1
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=2
# 2
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=3
# 3
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=4
# 4
# http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=5

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=1'
playload = {
'method':'search',
'searchMethod':'true',
'tenderUpdate':'',
'searchTarget':'',
'orgName':'',
'orgId':'',
'hid_1':'1',
'tenderName':'',
'tenderId':'',
'tenderType':'tenderDeclaration',
'tenderWay':'1,2,3,4,5,6,7,10,12',
'tenderDateRadio':'on',
'tenderStartDateStr':'105/02/13',
'tenderEndDateStr':'105/02/19',
'tenderStartDate':'105/02/19',
'tenderEndDate':'105/02/19',
'isSpdt':'N',
'proctrgCate':'3',
'radProctrgCate':'3',
'btnQuery':'查詢',
'hadUpdated':'',
}
res = requests.post(url,data=playload)
soup = BeautifulSoup(res.text)

# %%
div = soup.select('#print_area')[0]
trs = div.select('tr')[1:-1]
for tr in trs:
    print 'http://web.pcc.gov.tw/tps/' + tr.select('a')[0]['href'][3:]
# Out:
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814826
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814725
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814712
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51808145
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814003
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51799680
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813860
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813475
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815315
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815307
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815306
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815304
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815303
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815301
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815297
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815295
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815292
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815285
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815278
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815276
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815266
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815265
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815263
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815251
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815233
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815231
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815223
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815211
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815206
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815204
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815197
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815195
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815194
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815187
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815182
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815167
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815166
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815164
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815159
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815155
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815146
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815143
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815129
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815128
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815111
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815090
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815084
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815076
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815074
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815071
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815061
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815053
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815032
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815021
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815012
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815006
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814998
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814994
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814987
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814983
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814978
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814971
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814968
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814965
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814957
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814956
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814952
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814949
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814946
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814931
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814921
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814915
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814913
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814903
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814889
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814878
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814874
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814867
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814866
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814837
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51805264
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814836
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814832
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814831
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814830
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814829
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814825
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814821
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814819
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814817
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814816
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814814
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814813
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814811
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814794
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814783
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814782
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814779
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814776
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814771

# %%
dib_url = ['http://web.pcc.gov.tw/tps/' + tr.select('a')[0]['href'][3:]]
type(url)
# Out:
# str

# %%
for tr_url in dib_url:
    res_bid = requests.get(tr_url)
    soup = BeautifulSoup(res_bid.text)

# %%
print dib_url
# Out:
# ['http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51814771']

# %%
dib_url = 'http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813202'
res_bid = requests.get(dib_url)
soup = BeautifulSoup(res_bid.text)
to_file = soup.select('#print_area')[0]
file_id = dib_url.split('primaryKey=')[1]
f = open('/Users/Gsr00001/Desktop/ETLHomework/{}.text'.format(file_id),'w')
f.write(to_file.prettify().encode('utf-8'))
f.close()

# %%
import requests
import urlparse
from bs4 import BeautifulSoup
from math import ceil

# %%
payload = {
'method':'search',
'searchMethod':'true',
'tenderUpdate':'',
'searchTarget':'',
'orgName':'',
'orgId':'',
'hid_1':'1',
'tenderName':'',
'tenderId':'',
'tenderType':'tenderDeclaration',
'tenderWay':'1,2,3,4,5,6,7,10,12',
'tenderDateRadio':'on',
'tenderStartDateStr':'105/02/13',
'tenderEndDateStr':'105/02/19',
'tenderStartDate':'105/02/19',
'tenderEndDate':'105/02/19',
'isSpdt':'N',
'proctrgCate':'3',
'radProctrgCate':'3',
'btnQuery':'查詢',
'hadUpdated':'',
}
rs = requests.session()
user_post = rs.post('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=1',data=payload)
response_text = user_post.text.encode('utf8')

# %%
soup = BeautifulSoup(response_text)
rec_number_element = soup.select('.T11b')[0].text
page_number = int(ceil(float(rec_number_element)/100))
print page_number
# Out:
# 6

# %%
bid_file = open('bid_list.txt','w')
page_format = "http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=%d"
for page in range(1, page_number + 1):
    bid_list = rs.get(page_format%(page))
    bid_response = bid_list.text.encode('utf8')
    bid_soup = BeautifulSoup(bid_response)
    bid_div = bid_soup.select('#print_area')[0]
    bid_rows =  bid_div.select('tr')[1:-1]
    for bid_row in bid_rows:
        link = [tag['href'] for tag in bid_row.select('a')][0]
        link_href = urlparse.urljoin('http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=',link)
        bid_file.write(link_href + '\n')
bid_file.close()

# %%
line_num = 0
f = open('bid_list.txt', 'r')
for line in f.readlines():
    line_num = line_num +1
print line_num
f.close()
# Out:
# 567

# %%
import re
m = re.match(r"(?P<FirstName>\w+) (?P<LastName>\w+)", "Ken Lin")
print m.group("FirstName"), m.group("LastName")
# Out:
# Ken Lin

# %%
link = 'http://www.fnpc.gov.tw/html/ch/CFT.php?page=CFTBidInfo&area=C400&CFT_ID=1107'
t = re.match(r"([^ ]+)area=(?P<area>.+)&CFT_ID=(?P<CFT_ID>.+)", link)
print t.group('area'), t.group('CFT_ID')
# Out:
# C400 1107

# %%
link = 'http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51815362'
p = re.match(r"([^ ]+)&primaryKey=(?P<primaryKey>.+)", link)
print p.group('primaryKey')
# Out:
# 51815362

# %%
from bs4 import BeautifulSoup
import re, requests, time
bid_list = open('bid_list.txt', 'r')
for line in bid_list.readlines():
    pagelink = line.strip()
    m = re.match(r"([^ ]+)&primaryKey=(?P<primaryKey>.+)", pagelink)
    filename = pagelink.split('primaryKey=')[1]
    request_get = requests.get(pagelink)
    response = request_get.text.encode('utf8')
    soup = BeautifulSoup(response)
    printarea = soup.select('#print_area')[0]
    bid_detail = open('/Users/Gsr00001/Desktop/ETLhomework/{}.text'.format(filename),'w')
    bid_detail.write(printarea.prettify().encode('utf-8'))
    time.sleep(3)
    bid_detail.close()
bid_list.close()
